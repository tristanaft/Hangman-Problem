# %% [markdown]
# # My hangman file

# %%
import json
import numpy as np
import math
import requests
import random
import string
import secrets
import time
import re
import collections
from nltk import ngrams, FreqDist

# %%
class MyHangman(object):
    def __init__(self, weight_length = 1, weight_probability = 0.5, weight_count = 0.5, correct_word = "", full_dictionary_location = "words_250000_train.txt"):
        self.weight_length = weight_length
        self.weight_probability = weight_probability
        self.weight_count = weight_count
        self.guessed_letters = []
        if correct_word != "" :
            self.givenExternalWord = True
        else:
            self.givenExternalWord = False
        self.word = ""
        self.correct_word = correct_word
        full_dictionary_location = full_dictionary_location
        self.full_dictionary = self.build_dictionary(full_dictionary_location)        
        self.full_dictionary_common_letter_sorted = collections.Counter("".join(self.full_dictionary)).most_common()
        self.current_dictionary = []
        self.alphabet = list(string.ascii_lowercase)
        self.vowels = list(["a", "e", "i", "o", "u"])
        self.guess_list = []
        self.has_won = False
        self.gameLog = []
        #self.init_grams()
        self.allNGrams=self.generateNGrams(self.full_dictionary, 5)


    def changeWeights(self, wl, wp, wc):
        self.weight_length = wl
        self.weight_probabolity = wp
        self.weight_count = wc


    def generateNGrams(self, vocab, n):
        #return the ngrams as dictionaries
        #I used the freq_dists and ngrams from nltk but they are way too slow
        #this is a little confusing because I am loading words from a dictionary (not the data type) of words...
        #let's call it vocab instead
        allNGrams = []
        for k in range(2, n+1):
            ngrams = {}
            for word in vocab:
                word = "." + word + "." # pad with start and end bits
                if len(word) < k:
                    continue
                for i in range(len(word) - k + 1):
                    gram = word[i:i+k]
                    if gram not in ngrams:
                        ngrams[gram] = 1
                    else:
                        ngrams[gram] += 1
            allNGrams.append(ngrams.copy())

        return allNGrams
        
        
    def generate_correct_word(self):
        #Ok, so by default the code will generate a random correct word from the full dictionary
        #You can also initialize the class with an external correct word, or set one after initialization

        if self.givenExternalWord == False:
            self.correct_word = random.choice(self.full_dictionary)
    
    def set_correct_word(self, givenWord):
        self.correct_word = givenWord
        self.givenExternalWord = True


    def find_potential_guesses(self, allGrams, input_word, guess_list):
        
        potential_guesses = []
        remove_set = set(guess_list)
        remove_set.add(None)

        substr_list = []
        input_word = "." + input_word + "." #pad beginning and end with something to indicate beginning/end

        for i,char in enumerate(input_word):
            if char == "_": #found a blank
                start, end = i, i
                #print(i)
                #get longest substring containing the blank
                while start > 0 and input_word[start-1] != "_":
                    start-=1
                    #print(start)
                while end < len(input_word) - 1 and input_word[end+1] != "_":
                    end += 1
                    #print(end)
                substring = input_word[start : end + 1]
                substr_list.append(substring)
        #print(substr_list)

        for substr in substr_list:
            max_dim = min(len(substr), 5)
            current_dim = max_dim
            match_temp_array = []

            while current_dim >= 2:
                ngramDict = allGrams[current_dim - 2]

                grams = ngrams(substr, current_dim)
                subsubstr_list = ["".join(g) for g in grams if g.count("_") == 1]
                subsubstr_list = [x for x in subsubstr_list if (x != "_." and x != "._")]
                #print(subsubstr_list)
                
                for subsubstr in subsubstr_list:
                    print(subsubstr)
                    idx = subsubstr.find("_")
                    total_match_count = 0
                    for l in string.ascii_lowercase:
                        filledSubstr = str[0:idx] + l + str[idx+1::]
                        if(ngramDict.get(filledSubstr)):
                            count = ngramDict[filledSubstr]
                            match_temp_array.append([l, filledSubstr, count])
                            total_match_count += count
                            #print(l, count, filledSubstr, sep = " ")
                        for item in match_temp_array:
                            if (item[0] not in guess_list):
                                potential_guesses.append([item[0], current_dim, item[2] / total_match_count, total_match_count])
                
                print(match_temp_array)

                current_dim -= 1
            
        return potential_guesses
        

    def evaluate_potential_guesses(self, potential_guesses):
        #print(potential_guesses)
        if(potential_guesses == []):
            return "!" # no n-gram fits
        # Initialize dictionary to keep scores for each guess
        scores = {}

        # Weighting factors, these are the main thing to tweak...
        weight_probability = self.weight_probability
        weight_length = self.weight_length  # Giving more weight to the length of the n-gram
        weight_count = self.weight_count

        for guess, length, probability, tot_count in potential_guesses:
            guess_letter = list(guess)[0]  # Extract the letter from the set
            #if length == 2:
            #    continue

            # Calculate the score for this guess
            #score = probability * weight_probability + (length * weight_length) + weight_count * np.log(tot_count)
            score = np.log(probability * tot_count) * weight_count + weight_length * length

            # Add or update the score for this letter in the scores dictionary
            if guess_letter in scores:
                scores[guess_letter] += score
            else:
                scores[guess_letter] = score

        # Determine the best guess by finding the maximum score
        #print(scores)
        if len(scores) == 0:
            return "!"
        best_guess = max(scores, key=scores.get)
        return best_guess



    def guess(self, word): # word input example: "_ p p _ e "
        ###############################################
        # Replace with your own "guess" function here #
        ###############################################

        # clean the word so that we strip away the space characters
        # replace "_" with "." as "." indicates any character in regular expressions
        # The extra space characters must be coming from the website...
        clean_word = word.replace(" ", "") #I am putting this here in case I forget later to remove the space stuff when I paste this into the solution
        #clean_word = word.replace("_",".") #I am using underscores

        # find length of passed word
        len_word = len(clean_word)
        
        # grab current dictionary of possible words from self object, initialize new possible words dictionary to empty
        current_dictionary = self.current_dictionary
        new_dictionary = []
        #print(current_dictionary[0])
        
        # iterate through all of the words in the old plausible dictionary
        reMatchWord = clean_word.replace("_",".")
        for dict_word in current_dictionary:
            # continue if the word is not of the appropriate length
            if len(dict_word) != len_word:
                continue
                
            # if dictionary word is a possible match then add it to the current dictionary
            if re.match(reMatchWord, dict_word):
                new_dictionary.append(dict_word)
        
        # overwrite old possible words dictionary with updated version
        self.current_dictionary = new_dictionary
        
        
        # count occurrence of all characters in possible word matches
        full_dict_string = "".join(new_dictionary)
        
        c = collections.Counter(full_dict_string)
        sorted_letter_count = c.most_common()
        #print(sorted_letter_count)                
        
        #guess_letter = '!'

        all_guesses = self.find_potential_guesses(self.allNGrams, word, self.guessed_letters)
        #print(all_guesses)
        ngram_guess = self.evaluate_potential_guesses(all_guesses)
        
        
        # return most frequently occurring letter in all possible words that hasn't been guessed yet
        #print(sorted_letter_count)
        for letter,instance_count in sorted_letter_count:
            if letter not in self.guessed_letters:
                most_common_guess = letter
                #print(most_common_guess)
                break
        
        
        if(ngram_guess != "!"):
            return ngram_guess
        else:
            return most_common_guess
        #return most_common_guess


    ##########################################################
    # You'll likely not need to modify any of the code below #
    ##########################################################
    
    def build_dictionary(self, dictionary_file_location):
        text_file = open(dictionary_file_location,"r")
        full_dictionary = text_file.read().splitlines()
        text_file.close()
        return full_dictionary

    def handle_guess(self, guessLetter, currentWord, ans):
        #I have to convert the strings to lists, find indices of the letter (if present) and then smush the lists back into strings and spit it out
        indices = [i for i, x in enumerate(list(ans)) if x == guessLetter]
        wordList = list(currentWord)
        for i in indices:
            wordList[i] = guessLetter #now I replace the occurrences of the letter
        word = "".join(wordList)
        return word

    def get_winstate(self):
        return self.has_won
    
    def get_gamelog(self):
        return self.gameLog
        
                
    def start_game(self, practice=True, verbose=True):
        # reset guessed letters to empty set and current plausible dictionary to the full dictionary
        self.gameLog = []
        self.guessed_letters = []
        self.current_dictionary = self.full_dictionary
        self.has_won = False
        #pick a word from the dictionary at random.
        #correctWord = random.choice(self.full_dictionary) #this is the initial word, but need to update it based on guesses
        self.generate_correct_word()
        word = "_" * len(self.correct_word) #I should make this a member of self right?

        tries_remains = 6 #I think this needs to just be a magic number?
        
        self.gameLog.append([self.correct_word, word, self.guessed_letters.copy(), tries_remains])
        if verbose:
            print("Successfully start a new game! # of tries remaining: {0}. Word: {1}.".format(tries_remains, word))
        while tries_remains >0:
            #tries_remains -=1 tries remains decreases after WRONG answer

            #get guessed letter
            guess_letter = self.guess(word)

            #append guessed letter to guessed letters field in hangman object
            self.guessed_letters.append(guess_letter)
            

            if verbose:
                print("Guessing letter: {0}".format(guess_letter))

            #apply guessed letter to the word
            new_word = self.handle_guess(guess_letter, word, self.correct_word) 

            #check if we have the word
            if new_word == self.correct_word:
                word = new_word
                if verbose:
                    print("Success! the word was: %s" % word)
                self.has_won = True
                self.gameLog.append([self.correct_word, word, self.guessed_letters.copy(), tries_remains])
                break
            
            if new_word == word:
                #this means that we did not get a correct guess
                #decrease number of tries
                if verbose:
                    print("Incorrect guess {0}, # of tries remaining: {1}. Word: {2}.".format(guess_letter,tries_remains, word))
                tries_remains -=1
            else:
                #We have a correct letter guessed, but not the complete word
                #don't decrement tries_remains
                word = new_word
                if verbose:
                    print("Got a Letter, {0}, # of tries remaining: {1}. Word: {2}.".format(guess_letter,tries_remains, word))

            self.gameLog.append([self.correct_word, word, self.guessed_letters.copy(), tries_remains])
        if tries_remains == 0:
            if verbose:
                print("You Lose, the answer was: %s" % self.correct_word)

# %% [markdown]
# So... implementing a "probability" actually decreased how good the model is which is kinda sad...
#
# Also, even after messing with the code, it should be the same result as in 6 but it's not...
#
# So gotta fix that...

# %% [markdown]
# maybe the issue is the 2-grams... idk maybe it's better to start at 3...

# %%
game = MyHangman(weight_count = 0.25, weight_length = 2)
game.set_correct_word("ptilo")

# %%
game.start_game()
print()
# Out:
# Successfully start a new game! # of tries remaining: 6. Word: _____.
# []
# []
# Guessing letter: a
# Incorrect guess a, # of tries remaining: 6. Word: _____.
# []
# []
# Guessing letter: e
# Incorrect guess e, # of tries remaining: 5. Word: _____.
# []
# []
# Guessing letter: s
# Incorrect guess s, # of tries remaining: 4. Word: _____.
# []
# []
# Guessing letter: o
# Got a Letter, o, # of tries remaining: 3. Word: ____o.
# []
# _o.
# ae
# be
# ce
# de
# ee
# fe
# ge
# he
# ie
# je
# ke
# le
# me
# ne
# oe
# pe
# qe
# re
# se
# te
# ue
# ve
# we
# xe
# ye
# ze
# []
# _o
# ae
# ae
# be
# be
# ce
# ce
# de
# de
# ee
# ee
# fe
# fe
# ge
# ge
# he
# he
# ie
# ie
# je
# je
# ke
# ke
# le
# le
# me
# me
# ne
# ne
# oe
# oe
# pe
# pe
# qe
# qe
# re
# re
# se
# se
# te
# te
# ue
# ue
# ve
# ve
# we
# we
# xe
# xe
# ye
# ye
# ze
# ze
# [['a', 'ae', 3350], ['b', 'be', 5974], ['c', 'ce', 9023], ['d', 'de', 13954], ['e', 'ee', 5426], ['f', 'fe', 3328], ['g', 'ge', 7326], ['h', 'he', 11707], ['i', 'ie', 8301], ['j', 'je', 735], ['k', 'ke', 5188], ['l', 'le', 22135], ['m', 'me', 11077], ['n', 'ne', 19584], ['o', 'oe', 1715], ['p', 'pe', 10209], ['q', 'qe', 5], ['r', 're', 24800], ['s', 'se', 13813], ['t', 'te', 26219], ['u', 'ue', 2259], ['v', 've', 10593], ['w', 'we', 3228], ['x', 'xe', 638], ['y', 'ye', 1380], ['z', 'ze', 3531]]
# Guessing letter: b
# Incorrect guess b, # of tries remaining: 3. Word: ____o.
# []
# _o.
# ae
# be
# ce
# de
# ee
# fe
# ge
# he
# ie
# je
# ke
# le
# me
# ne
# oe
# pe
# qe
# re
# se
# te
# ue
# ve
# we
# xe
# ye
# ze
# []
# _o
# ae
# ae
# be
# be
# ce
# ce
# de
# de
# ee
# ee
# fe
# fe
# ge
# ge
# he
# he
# ie
# ie
# je
# je
# ke
# ke
# le
# le
# me
# me
# ne
# ne
# oe
# oe
# pe
# pe
# qe
# qe
# re
# re
# se
# se
# te
# te
# ue
# ue
# ve
# ve
# we
# we
# xe
# xe
# ye
# ye
# ze
# ze
# [['a', 'ae', 3350], ['b', 'be', 5974], ['c', 'ce', 9023], ['d', 'de', 13954], ['e', 'ee', 5426], ['f', 'fe', 3328], ['g', 'ge', 7326], ['h', 'he', 11707], ['i', 'ie', 8301], ['j', 'je', 735], ['k', 'ke', 5188], ['l', 'le', 22135], ['m', 'me', 11077], ['n', 'ne', 19584], ['o', 'oe', 1715], ['p', 'pe', 10209], ['q', 'qe', 5], ['r', 're', 24800], ['s', 'se', 13813], ['t', 'te', 26219], ['u', 'ue', 2259], ['v', 've', 10593], ['w', 'we', 3228], ['x', 'xe', 638], ['y', 'ye', 1380], ['z', 'ze', 3531]]
# Guessing letter: c
# Incorrect guess c, # of tries remaining: 2. Word: ____o.
# []
# _o.
# ae
# be
# ce
# de
# ee
# fe
# ge
# he
# ie
# je
# ke
# le
# me
# ne
# oe
# pe
# qe
# re
# se
# te
# ue
# ve
# we
# xe
# ye
# ze
# []
# _o
# ae
# ae
# be
# be
# ce
# ce
# de
# de
# ee
# ee
# fe
# fe
# ge
# ge
# he
# he
# ie
# ie
# je
# je
# ke
# ke
# le
# le
# me
# me
# ne
# ne
# oe
# oe
# pe
# pe
# qe
# qe
# re
# re
# se
# se
# te
# te
# ue
# ue
# ve
# ve
# we
# we
# xe
# xe
# ye
# ye
# ze
# ze
# [['a', 'ae', 3350], ['b', 'be', 5974], ['c', 'ce', 9023], ['d', 'de', 13954], ['e', 'ee', 5426], ['f', 'fe', 3328], ['g', 'ge', 7326], ['h', 'he', 11707], ['i', 'ie', 8301], ['j', 'je', 735], ['k', 'ke', 5188], ['l', 'le', 22135], ['m', 'me', 11077], ['n', 'ne', 19584], ['o', 'oe', 1715], ['p', 'pe', 10209], ['q', 'qe', 5], ['r', 're', 24800], ['s', 'se', 13813], ['t', 'te', 26219], ['u', 'ue', 2259], ['v', 've', 10593], ['w', 'we', 3228], ['x', 'xe', 638], ['y', 'ye', 1380], ['z', 'ze', 3531]]
# Guessing letter: d
# Incorrect guess d, # of tries remaining: 1. Word: ____o.
# You Lose, the answer was: ptilo

# %%
game.changeWeights(1,1,1)

# %% [markdown]
# Ok... I have successfully replicated how NGRAM 6 works... so now I can see whether that method is indeed better... In the previous file I tweaked way too much stuff. I modified how the ngrams are stored and accessed, from freq_dist in the nltk package, to dictionaries. This was to speed up the actual calculations. But I also modified how the algorithm picked guesses...
#
# So let's go back to tweaking parameters?

# %%
game.get_winstate()
# Out:
# True

# %% [markdown]
# dict reducing method is ~87% on TRAINING data but bad on new data

# %%
game = MyHangman(weight_count = 0.25, weight_length = 2)
wincount = 0
N = 1000
for i in range(N):
    if i % (N/10) == 0:
        print("on game %i of %i" % (i+1, N))
        win_percent = 100*wincount/(i+1)
        print("win percentage: %f" % win_percent)
    game.start_game(verbose=False)
    wincount += game.get_winstate()
print()
print("win percentage: ", 100*wincount/N, "%")
# Out:
# on game 1 of 1000
# win percentage: 0.000000
# on game 101 of 1000
# win percentage: 55.445545
# on game 201 of 1000
# win percentage: 56.218905
# on game 301 of 1000
# win percentage: 54.152824
# on game 401 of 1000
# win percentage: 55.112219
# on game 501 of 1000
# win percentage: 57.285429
# on game 601 of 1000
# win percentage: 57.237937
# on game 701 of 1000
# win percentage: 58.059914
# on game 801 of 1000
# win percentage: 58.926342
# on game 901 of 1000
# win percentage: 58.712542
#
# win percentage:  59.6 %

# %% [markdown]
# Yeah, so picking the longest substring to make a guess gives ~10% gain in accuracy... cool. At least with the current parameters. Tweaking them could improve performance.

# %%
game = MyHangman()
gridScores = []
weight_count_vector = np.linspace(0, 0.5, 11)
weight_length_vector = np.linspace(0, 5, 11)
M = len(weight_count_vector) * len(weight_length_vector)
#MyHangman(weight_count = 0.25, weight_length = 2) best performance so far...

tr = 0
for wc in weight_count_vector:
    for wl in weight_length_vector:
        tr += 1
        game.changeWeights(wl, 0, wc)
        wincount = 0
        N = 1000
        for i in range(N):
            #if i % (N/10) == 0:
                #print("on game %i of %i" % (i+1, N))
                #win_percent = 100*wincount/(i+1)
                #print("win percentage: %f" % win_percent)
            game.start_game(verbose=False)
            wincount += game.get_winstate()
        print("Finished trial %i of %i" % (tr, M))
        print("win percentage: ", 100*wincount/N, "%")
        print()
        gridScores.append([wl, wc, 100*wincount/N])
# Out:
# Finished trial 1 of 121
# win percentage:  4.8 %
#
# Finished trial 2 of 121
# win percentage:  14.2 %
#
# Finished trial 3 of 121
# win percentage:  17.8 %
#
# Finished trial 4 of 121
# win percentage:  14.6 %
#
# Finished trial 5 of 121
# win percentage:  14.8 %
#
# Finished trial 6 of 121
# win percentage:  16.5 %
#
# Finished trial 7 of 121
# win percentage:  18.3 %
#
# Finished trial 8 of 121
# win percentage:  17.8 %
#
# Finished trial 9 of 121
# win percentage:  16.5 %
#
# Finished trial 10 of 121
# win percentage:  16.3 %
#
# Finished trial 11 of 121
# win percentage:  17.7 %
#
# Finished trial 12 of 121
# win percentage:  60.4 %
#
# Finished trial 13 of 121
# win percentage:  61.0 %
#
# Finished trial 14 of 121
# win percentage:  58.3 %
#
# Finished trial 15 of 121
# win percentage:  61.5 %
#
# Finished trial 16 of 121
# win percentage:  60.3 %
#
# Finished trial 17 of 121
# win percentage:  63.3 %
#
# Finished trial 18 of 121
# win percentage:  61.0 %
#
# Finished trial 19 of 121
# win percentage:  60.7 %
#
# Finished trial 20 of 121
# win percentage:  60.8 %
#
# Finished trial 21 of 121
# win percentage:  63.0 %
#
# Finished trial 22 of 121
# win percentage:  61.1 %
#
# Finished trial 23 of 121
# win percentage:  59.7 %
#
# Finished trial 24 of 121
# win percentage:  64.1 %
#
# Finished trial 25 of 121
# win percentage:  57.1 %
#
# Finished trial 26 of 121
# win percentage:  59.4 %
#
# Finished trial 27 of 121
# win percentage:  61.3 %
#
# Finished trial 28 of 121
# win percentage:  60.0 %
#
# Finished trial 29 of 121
# win percentage:  62.9 %
#
# Finished trial 30 of 121
# win percentage:  59.9 %
#
# Finished trial 31 of 121
# win percentage:  60.7 %
#
# Finished trial 32 of 121
# win percentage:  60.7 %
#
# Finished trial 33 of 121
# win percentage:  62.2 %
#
# Finished trial 34 of 121
# win percentage:  60.2 %
#
# Finished trial 35 of 121
# win percentage:  63.9 %
#
# Finished trial 36 of 121
# win percentage:  60.4 %
#
# Finished trial 37 of 121
# win percentage:  60.5 %
#
# Finished trial 38 of 121
# win percentage:  60.9 %
#
# Finished trial 39 of 121
# win percentage:  63.1 %
#
# Finished trial 40 of 121
# win percentage:  61.7 %
#
# Finished trial 41 of 121
# win percentage:  60.8 %
#
# Finished trial 42 of 121
# win percentage:  59.4 %
#
# Finished trial 43 of 121
# win percentage:  58.1 %
#
# Finished trial 44 of 121
# win percentage:  61.5 %
#
# Finished trial 45 of 121
# win percentage:  59.8 %
#
# Finished trial 46 of 121
# win percentage:  61.6 %
#
# Finished trial 47 of 121
# win percentage:  61.5 %
#
# Finished trial 48 of 121
# win percentage:  61.8 %
#
# Finished trial 49 of 121
# win percentage:  63.3 %
#
# Finished trial 50 of 121
# win percentage:  60.0 %
#
# Finished trial 51 of 121
# win percentage:  61.4 %
#
# Finished trial 52 of 121
# win percentage:  63.6 %
#
# Finished trial 53 of 121
# win percentage:  60.2 %
#
# Finished trial 54 of 121
# win percentage:  60.8 %
#
# Finished trial 55 of 121
# win percentage:  60.8 %
#
# Finished trial 56 of 121
# win percentage:  58.4 %
#
# Finished trial 57 of 121
# win percentage:  60.8 %
#
# Finished trial 58 of 121
# win percentage:  61.1 %
#
# Finished trial 59 of 121
# win percentage:  61.7 %
#
# Finished trial 60 of 121
# win percentage:  62.1 %
#
# Finished trial 61 of 121
# win percentage:  62.0 %
#
# Finished trial 62 of 121
# win percentage:  62.1 %
#
# Finished trial 63 of 121
# win percentage:  59.8 %
#
# Finished trial 64 of 121
# win percentage:  61.2 %
#
# Finished trial 65 of 121
# win percentage:  60.2 %
#
# Finished trial 66 of 121
# win percentage:  60.9 %
#
# Finished trial 67 of 121
# win percentage:  56.8 %
#
# Finished trial 68 of 121
# win percentage:  59.0 %
#
# Finished trial 69 of 121
# win percentage:  60.3 %
#
# Finished trial 70 of 121
# win percentage:  62.6 %
#
# Finished trial 71 of 121
# win percentage:  59.6 %
#
# Finished trial 72 of 121
# win percentage:  60.5 %
#
# Finished trial 73 of 121
# win percentage:  63.5 %
#
# Finished trial 74 of 121
# win percentage:  60.5 %
#
# Finished trial 75 of 121
# win percentage:  60.5 %
#
# Finished trial 76 of 121
# win percentage:  61.0 %
#
# Finished trial 77 of 121
# win percentage:  62.5 %
#
# Finished trial 78 of 121
# win percentage:  61.3 %
#
# Finished trial 79 of 121
# win percentage:  60.5 %
#
# Finished trial 80 of 121
# win percentage:  60.6 %
#
# Finished trial 81 of 121
# win percentage:  59.5 %
#
# Finished trial 82 of 121
# win percentage:  60.3 %
#
# Finished trial 83 of 121
# win percentage:  61.2 %
#
# Finished trial 84 of 121
# win percentage:  62.2 %
#
# Finished trial 85 of 121
# win percentage:  64.0 %
#
# Finished trial 86 of 121
# win percentage:  59.6 %
#
# Finished trial 87 of 121
# win percentage:  62.1 %
#
# Finished trial 88 of 121
# win percentage:  62.3 %
#
# Finished trial 89 of 121
# win percentage:  57.4 %
#
# Finished trial 90 of 121
# win percentage:  62.8 %
#
# Finished trial 91 of 121
# win percentage:  62.5 %
#
# Finished trial 92 of 121
# win percentage:  62.2 %
#
# Finished trial 93 of 121
# win percentage:  61.8 %
#
# Finished trial 94 of 121
# win percentage:  60.0 %
#
# Finished trial 95 of 121
# win percentage:  59.7 %
#
# Finished trial 96 of 121
# win percentage:  63.0 %
#
# Finished trial 97 of 121
# win percentage:  61.7 %
#
# Finished trial 98 of 121
# win percentage:  63.2 %
#
# Finished trial 99 of 121
# win percentage:  60.0 %
#
# Finished trial 100 of 121
# win percentage:  60.8 %
#
# Finished trial 101 of 121
# win percentage:  60.4 %
#
# Finished trial 102 of 121
# win percentage:  64.0 %
#
# Finished trial 103 of 121
# win percentage:  61.9 %
#
# Finished trial 104 of 121
# win percentage:  62.1 %
#
# Finished trial 105 of 121
# win percentage:  64.1 %
#
# Finished trial 106 of 121
# win percentage:  64.9 %
#
# Finished trial 107 of 121
# win percentage:  60.8 %
#
# Finished trial 108 of 121
# win percentage:  62.2 %
#
# Finished trial 109 of 121
# win percentage:  63.2 %
#
# Finished trial 110 of 121
# win percentage:  61.3 %
#
# Finished trial 111 of 121
# win percentage:  60.0 %
#
# Finished trial 112 of 121
# win percentage:  63.4 %
#
# Finished trial 113 of 121
# win percentage:  59.5 %
#
# Finished trial 114 of 121
# win percentage:  59.9 %
#
# Finished trial 115 of 121
# win percentage:  63.4 %
#
# Finished trial 116 of 121
# win percentage:  60.7 %
#
# Finished trial 117 of 121
# win percentage:  61.7 %
#
# Finished trial 118 of 121
# win percentage:  61.0 %
#
# Finished trial 119 of 121
# win percentage:  62.3 %
#
# Finished trial 120 of 121
# win percentage:  62.7 %
#
# Finished trial 121 of 121
# win percentage:  62.9 %

# %%
gridScores.sort(key = lambda x: x[2], reverse = True)
top_20 = gridScores[0:20]
print(top_20)
# Out:
# [[3.0, 0.45, 64.9], [0.5, 0.1, 64.1], [2.5, 0.45, 64.1], [3.5, 0.35000000000000003, 64.0], [1.0, 0.45, 64.0], [0.5, 0.15000000000000002, 63.9], [3.5, 0.2, 63.6], [3.0, 0.30000000000000004, 63.5], [0.5, 0.5, 63.4], [2.0, 0.5, 63.4], [2.5, 0.05, 63.3], [2.0, 0.2, 63.3], [4.5, 0.4, 63.2], [4.5, 0.45, 63.2], [2.5, 0.15000000000000002, 63.1], [4.5, 0.05, 63.0], [3.5, 0.4, 63.0], [3.0, 0.1, 62.9], [5.0, 0.5, 62.9], [0.5, 0.4, 62.8]]

# %%
top_20 = [[3.0, 0.45, 64.9], [0.5, 0.1, 64.1], [2.5, 0.45, 64.1], [3.5, 0.35000000000000003, 64.0], [1.0, 0.45, 64.0], [0.5, 0.15000000000000002, 63.9], [3.5, 0.2, 63.6], [3.0, 0.30000000000000004, 63.5], [0.5, 0.5, 63.4], [2.0, 0.5, 63.4], [2.5, 0.05, 63.3], [2.0, 0.2, 63.3], [4.5, 0.4, 63.2], [4.5, 0.45, 63.2], [2.5, 0.15000000000000002, 63.1], [4.5, 0.05, 63.0], [3.5, 0.4, 63.0], [3.0, 0.1, 62.9], [5.0, 0.5, 62.9], [0.5, 0.4, 62.8]]

# %% [markdown]
# Ok, so I have the 20 best set, let's check them with a bit more trials

# %%
game = MyHangman()

# %%
M = len(top_20)
#MyHangman(weight_count = 0.25, weight_length = 2) best performance so far...

tr = 0
top_20_checked = []
for item in top_20:
    wl = item[0]
    wc = item[1]
    tr += 1
    game.changeWeights(wl, 0, wc)
    wincount = 0
    N = 5000
    for i in range(N):
        if i % (N/10) == 0:
            print("on game %i of %i" % (i+1, N))
            win_percent = 100*wincount/(i+1)
            print("win percentage: %f" % win_percent)
        game.start_game(verbose=False)
        wincount += game.get_winstate()
    print("Finished trial %i of %i" % (tr, M))
    print("win percentage: ", 100*wincount/N, "%")
    print()
    top_20_checked.append([wl, wc, 100*wincount/N])
# Out:
# on game 1 of 5000
# win percentage: 0.000000
# on game 501 of 5000
# win percentage: 56.287425
# on game 1001 of 5000
# win percentage: 58.641359
# on game 1501 of 5000
# win percentage: 59.626915
# on game 2001 of 5000
# win percentage: 60.719640
# on game 2501 of 5000
# win percentage: 60.255898
# on game 3001 of 5000
# win percentage: 60.479840
# on game 3501 of 5000
# win percentage: 60.582691
# on game 4001 of 5000
# win percentage: 60.609848
# on game 4501 of 5000
# win percentage: 61.141968
# Finished trial 1 of 20
# win percentage:  60.94 %
#
# on game 1 of 5000
# win percentage: 0.000000
# on game 501 of 5000
# win percentage: 63.073852
# on game 1001 of 5000
# win percentage: 59.840160
# on game 1501 of 5000
# win percentage: 60.293138
# on game 2001 of 5000
# win percentage: 60.319840
# on game 2501 of 5000
# win percentage: 61.255498
# on game 3001 of 5000
# win percentage: 61.146285
# on game 3501 of 5000
# win percentage: 61.153956
# on game 4001 of 5000
# win percentage: 60.859785
# on game 4501 of 5000
# win percentage: 61.364141
# Finished trial 2 of 20
# win percentage:  61.54 %
#
# on game 1 of 5000
# win percentage: 0.000000
# on game 501 of 5000
# win percentage: 59.680639
# on game 1001 of 5000
# win percentage: 61.338661
# on game 1501 of 5000
# win percentage: 61.359094
# on game 2001 of 5000
# win percentage: 61.669165
# on game 2501 of 5000
# win percentage: 62.415034
# on game 3001 of 5000
# win percentage: 62.612463
# on game 3501 of 5000
# win percentage: 62.010854
# on game 4001 of 5000
# win percentage: 62.034491
# on game 4501 of 5000
# win percentage: 61.764052
# Finished trial 3 of 20
# win percentage:  61.82 %
#
# on game 1 of 5000
# win percentage: 0.000000
# on game 501 of 5000
# win percentage: 59.880240
# on game 1001 of 5000
# win percentage: 58.641359
# on game 1501 of 5000
# win percentage: 60.759494
# on game 2001 of 5000
# win percentage: 60.169915
# on game 2501 of 5000
# win percentage: 60.615754
# on game 3001 of 5000
# win percentage: 60.479840
# on game 3501 of 5000
# win percentage: 60.411311
# on game 4001 of 5000
# win percentage: 60.159960
# on game 4501 of 5000
# win percentage: 60.453233
# Finished trial 4 of 20
# win percentage:  60.46 %
#
# on game 1 of 5000
# win percentage: 0.000000
# on game 501 of 5000
# win percentage: 58.083832
# on game 1001 of 5000
# win percentage: 59.540460
# on game 1501 of 5000
# win percentage: 61.359094
# on game 2001 of 5000
# win percentage: 61.519240
# on game 2501 of 5000
# win percentage: 62.015194
# on game 3001 of 5000
# win percentage: 62.245918
# on game 3501 of 5000
# win percentage: 62.439303
# on game 4001 of 5000
# win percentage: 62.234441
# on game 4501 of 5000
# win percentage: 62.163964
# Finished trial 5 of 20
# win percentage:  61.98 %
#
# on game 1 of 5000
# win percentage: 0.000000
# on game 501 of 5000
# win percentage: 60.279441
# on game 1001 of 5000
# win percentage: 60.039960
# on game 1501 of 5000
# win percentage: 61.359094
# on game 2001 of 5000
# win percentage: 61.019490
# on game 2501 of 5000
# win percentage: 60.735706
# on game 3001 of 5000
# win percentage: 61.079640
# on game 3501 of 5000
# win percentage: 60.954013
# on game 4001 of 5000
# win percentage: 61.284679
# on game 4501 of 5000
# win percentage: 61.586314
# Finished trial 6 of 20
# win percentage:  61.52 %
#
# on game 1 of 5000
# win percentage: 0.000000
# on game 501 of 5000
# win percentage: 62.275449
# on game 1001 of 5000
# win percentage: 61.138861
# on game 1501 of 5000
# win percentage: 62.158561
# on game 2001 of 5000
# win percentage: 62.768616
# on game 2501 of 5000
# win percentage: 62.734906
# on game 3001 of 5000
# win percentage: 62.512496
# on game 3501 of 5000
# win percentage: 61.953728
# on game 4001 of 5000
# win percentage: 61.859535
# on game 4501 of 5000
# win percentage: 61.897356
# Finished trial 7 of 20
# win percentage:  61.84 %
#
# on game 1 of 5000
# win percentage: 0.000000
# on game 501 of 5000
# win percentage: 59.880240
# on game 1001 of 5000
# win percentage: 60.239760
# on game 1501 of 5000
# win percentage: 60.226516
# on game 2001 of 5000
# win percentage: 59.920040
# on game 2501 of 5000
# win percentage: 60.855658
# on game 3001 of 5000
# win percentage: 61.112962
# on game 3501 of 5000
# win percentage: 61.582405
# on game 4001 of 5000
# win percentage: 61.309673
# on game 4501 of 5000
# win percentage: 61.208620
# Finished trial 8 of 20
# win percentage:  61.2 %
#
# on game 1 of 5000
# win percentage: 0.000000
# on game 501 of 5000
# win percentage: 64.271457
# on game 1001 of 5000
# win percentage: 63.936064
# on game 1501 of 5000
# win percentage: 64.157229
# on game 2001 of 5000
# win percentage: 63.168416
# on game 2501 of 5000
# win percentage: 63.094762
# on game 3001 of 5000
# win percentage: 63.378874
# on game 3501 of 5000
# win percentage: 63.096258
# on game 4001 of 5000
# win percentage: 63.409148
# on game 4501 of 5000
# win percentage: 63.008220
# Finished trial 9 of 20
# win percentage:  62.7 %
#
# on game 1 of 5000
# win percentage: 0.000000
# on game 501 of 5000
# win percentage: 62.475050
# on game 1001 of 5000
# win percentage: 62.037962
# on game 1501 of 5000
# win percentage: 60.826116
# on game 2001 of 5000
# win percentage: 60.919540
# on game 2501 of 5000
# win percentage: 60.335866
# on game 3001 of 5000
# win percentage: 60.113296
# on game 3501 of 5000
# win percentage: 60.868323
# on game 4001 of 5000
# win percentage: 60.559860
# on game 4501 of 5000
# win percentage: 60.142191
# Finished trial 10 of 20
# win percentage:  60.1 %
#
# on game 1 of 5000
# win percentage: 0.000000
# on game 501 of 5000
# win percentage: 64.271457
# on game 1001 of 5000
# win percentage: 60.939061
# on game 1501 of 5000
# win percentage: 61.625583
# on game 2001 of 5000
# win percentage: 61.569215
# on game 2501 of 5000
# win percentage: 61.335466
# on game 3001 of 5000
# win percentage: 61.212929
# on game 3501 of 5000
# win percentage: 60.954013
# on game 4001 of 5000
# win percentage: 60.909773
# on game 4501 of 5000
# win percentage: 61.164186
# Finished trial 11 of 20
# win percentage:  61.28 %
#
# on game 1 of 5000
# win percentage: 0.000000
# on game 501 of 5000
# win percentage: 64.271457
# on game 1001 of 5000
# win percentage: 64.935065
# on game 1501 of 5000
# win percentage: 63.690873
# on game 2001 of 5000
# win percentage: 63.318341
# on game 2501 of 5000
# win percentage: 62.534986
# on game 3001 of 5000
# win percentage: 62.879040
# on game 3501 of 5000
# win percentage: 62.839189
# on game 4001 of 5000
# win percentage: 62.659335
# on game 4501 of 5000
# win percentage: 62.408354
# Finished trial 12 of 20
# win percentage:  62.5 %
#
# on game 1 of 5000
# win percentage: 0.000000
# on game 501 of 5000
# win percentage: 61.876248
# on game 1001 of 5000
# win percentage: 62.437562
# on game 1501 of 5000
# win percentage: 62.558294
# on game 2001 of 5000
# win percentage: 62.618691
# on game 2501 of 5000
# win percentage: 62.894842
# on game 3001 of 5000
# win percentage: 62.079307
# on game 3501 of 5000
# win percentage: 61.810911
# on game 4001 of 5000
# win percentage: 61.634591
# on game 4501 of 5000
# win percentage: 61.697401
# Finished trial 13 of 20
# win percentage:  61.84 %
#
# on game 1 of 5000
# win percentage: 0.000000
# on game 501 of 5000
# win percentage: 60.079840
# on game 1001 of 5000
# win percentage: 60.439560
# on game 1501 of 5000
# win percentage: 60.826116
# on game 2001 of 5000
# win percentage: 60.819590
# on game 2501 of 5000
# win percentage: 60.735706
# on game 3001 of 5000
# win percentage: 60.279907
# on game 3501 of 5000
# win percentage: 60.611254
# on game 4001 of 5000
# win percentage: 60.434891
# on game 4501 of 5000
# win percentage: 60.564319
# Finished trial 14 of 20
# win percentage:  60.88 %
#
# on game 1 of 5000
# win percentage: 0.000000
# on game 501 of 5000
# win percentage: 61.876248
# on game 1001 of 5000
# win percentage: 61.238761
# on game 1501 of 5000
# win percentage: 60.692871
# on game 2001 of 5000
# win percentage: 59.920040
# on game 2501 of 5000
# win percentage: 60.135946
# on game 3001 of 5000
# win percentage: 59.913362
# on game 3501 of 5000
# win percentage: 60.497001
# on game 4001 of 5000
# win percentage: 60.034991
# on game 4501 of 5000
# win percentage: 60.008887
# Finished trial 15 of 20
# win percentage:  60.14 %
#
# on game 1 of 5000
# win percentage: 0.000000
# on game 501 of 5000
# win percentage: 57.285429
# on game 1001 of 5000
# win percentage: 60.539461
# on game 1501 of 5000
# win percentage: 60.093271
# on game 2001 of 5000
# win percentage: 60.119940
# on game 2501 of 5000
# win percentage: 61.135546
# on game 3001 of 5000
# win percentage: 60.979673
# on game 3501 of 5000
# win percentage: 61.011140
# on game 4001 of 5000
# win percentage: 60.884779
# on game 4501 of 5000
# win percentage: 61.253055
# Finished trial 16 of 20
# win percentage:  60.88 %
#
# on game 1 of 5000
# win percentage: 0.000000
# on game 501 of 5000
# win percentage: 61.077844
# on game 1001 of 5000
# win percentage: 62.637363
# on game 1501 of 5000
# win percentage: 62.758161
# on game 2001 of 5000
# win percentage: 62.018991
# on game 2501 of 5000
# win percentage: 61.295482
# on game 3001 of 5000
# win percentage: 61.512829
# on game 3501 of 5000
# win percentage: 61.325336
# on game 4001 of 5000
# win percentage: 61.384654
# on game 4501 of 5000
# win percentage: 61.386359
# Finished trial 17 of 20
# win percentage:  61.52 %
#
# on game 1 of 5000
# win percentage: 0.000000
# on game 501 of 5000
# win percentage: 64.471058
# on game 1001 of 5000
# win percentage: 60.739261
# on game 1501 of 5000
# win percentage: 60.826116
# on game 2001 of 5000
# win percentage: 61.419290
# on game 2501 of 5000
# win percentage: 61.895242
# on game 3001 of 5000
# win percentage: 61.846051
# on game 3501 of 5000
# win percentage: 61.582405
# on game 4001 of 5000
# win percentage: 61.634591
# on game 4501 of 5000
# win percentage: 61.186403
# Finished trial 18 of 20
# win percentage:  61.28 %
#
# on game 1 of 5000
# win percentage: 0.000000
# on game 501 of 5000
# win percentage: 61.077844
# on game 1001 of 5000
# win percentage: 61.938062
# on game 1501 of 5000
# win percentage: 61.892072
# on game 2001 of 5000
# win percentage: 61.669165
# on game 2501 of 5000
# win percentage: 61.255498
# on game 3001 of 5000
# win percentage: 61.279573
# on game 3501 of 5000
# win percentage: 61.839474
# on game 4001 of 5000
# win percentage: 61.684579
# on game 4501 of 5000
# win percentage: 61.564097
# Finished trial 19 of 20
# win percentage:  61.54 %
#
# on game 1 of 5000
# win percentage: 0.000000
# on game 501 of 5000
# win percentage: 58.882236
# on game 1001 of 5000
# win percentage: 61.338661
# on game 1501 of 5000
# win percentage: 61.558961
# on game 2001 of 5000
# win percentage: 62.718641
# on game 2501 of 5000
# win percentage: 62.295082
# on game 3001 of 5000
# win percentage: 62.112629
# on game 3501 of 5000
# win percentage: 62.067981
# on game 4001 of 5000
# win percentage: 62.309423
# on game 4501 of 5000
# win percentage: 62.230615
# Finished trial 20 of 20
# win percentage:  62.1 %

# %%
top_20_checked.sort(key = lambda x: x[2], reverse = True)
print(top_20_checked)
# Out:
# [[0.5, 0.5, 62.7], [2.0, 0.2, 62.5], [0.5, 0.4, 62.1], [1.0, 0.45, 61.98], [3.5, 0.2, 61.84], [4.5, 0.4, 61.84], [2.5, 0.45, 61.82], [0.5, 0.1, 61.54], [5.0, 0.5, 61.54], [0.5, 0.15000000000000002, 61.52], [3.5, 0.4, 61.52], [2.5, 0.05, 61.28], [3.0, 0.1, 61.28], [3.0, 0.30000000000000004, 61.2], [3.0, 0.45, 60.94], [4.5, 0.45, 60.88], [4.5, 0.05, 60.88], [3.5, 0.35000000000000003, 60.46], [2.5, 0.15000000000000002, 60.14], [2.0, 0.5, 60.1]]

# %%
top_20_checked = [[0.5, 0.5, 62.7], [2.0, 0.2, 62.5], [0.5, 0.4, 62.1], [1.0, 0.45, 61.98], [3.5, 0.2, 61.84], [4.5, 0.4, 61.84], [2.5, 0.45, 61.82], [0.5, 0.1, 61.54], [5.0, 0.5, 61.54], [0.5, 0.15000000000000002, 61.52], [3.5, 0.4, 61.52], [2.5, 0.05, 61.28], [3.0, 0.1, 61.28], [3.0, 0.30000000000000004, 61.2], [3.0, 0.45, 60.94], [4.5, 0.45, 60.88], [4.5, 0.05, 60.88], [3.5, 0.35000000000000003, 60.46], [2.5, 0.15000000000000002, 60.14], [2.0, 0.5, 60.1]][[0.5, 0.5, 62.7], [2.0, 0.2, 62.5], [0.5, 0.4, 62.1], [1.0, 0.45, 61.98], [3.5, 0.2, 61.84], [4.5, 0.4, 61.84], [2.5, 0.45, 61.82], [0.5, 0.1, 61.54], [5.0, 0.5, 61.54], [0.5, 0.15000000000000002, 61.52], [3.5, 0.4, 61.52], [2.5, 0.05, 61.28], [3.0, 0.1, 61.28], [3.0, 0.30000000000000004, 61.2], [3.0, 0.45, 60.94], [4.5, 0.45, 60.88], [4.5, 0.05, 60.88], [3.5, 0.35000000000000003, 60.46], [2.5, 0.15000000000000002, 60.14], [2.0, 0.5, 60.1]]

# %%
print("win percentage: ", 100*wincount/N, "%")
# Out:
# win percentage:  64.0 %

# %% [markdown]
# This is a significant improvement... hopefully... but it still isn't good enough in my opinion... I at least have parameters to tweak? It would be easier to mass tweak parameters if it was faster.

# %% [markdown]
# Am I doing things wrong? I am still using the FULL dictionary to train the algorithm and test it. I need to test the algorithm on UNKNOWN words. I need to do a test/train split or load another data file.

# %%
tf = open("words_250000_train.txt","r")
full_dict = tf.read().splitlines()
tf.close()

# %%
tf = open("words_test.txt","r")
test_dict = tf.read().splitlines()
tf.close()

# %%
len(full_dict)
# Out:
# 227300

# %%
len(test_dict)
# Out:
# 170671

# %%
len(full_dict)/len(test_dict)
# Out:
# 1.3318021222117407

# %%
def generateNGrams(vocab, n):
    #return the ngrams as dictionaries
    #this is a little confusing because I am loading words from a dictionary (not the data type) of words...
    #let's call it vocab instead
    ngrams = {}
    for word in vocab:
        word = "." + word + "." # pad with start and end bits
        if len(word) < n:
            continue
        for i in range(len(word) - n + 1):
            gram = word[i:i+n]
            if gram not in ngrams:
                ngrams[gram] = 1
            else:
                ngrams[gram] += 1
    return ngrams

ngrams=[generateNGrams(full_dict,i) for i in range(1,6)]

# %%
def getNGrams(words,n):
    ngrams = {}
    for word in words:
        if len(word) <n:
            continue
        for i in range(len(word)-n+1):
            ngram = word[i:i+n]
            if ngram not in ngrams:
                ngrams[ngram] = 1
            else:
                ngrams[ngram]+=1
    return ngrams

ngrams=[getNGrams(full_dict,i) for i in range(1,6)]

# %%
def ngramprob(word,letter):
        denominator=0
        underscroll_location=word.find("_")
        for l in string.ascii_lowercase:            
            try:
                denominator+=ngrams[len(word)-1][word[:underscroll_location]+l+word[underscroll_location+1:]]
                print(word[:underscroll_location]+l+word[underscroll_location+1:])
            except:
                pass
        return ngrams[len(word)-1][word[:underscroll_location]+letter+word[underscroll_location+1:]]/denominator

# %%
ngramprob("pp_e","l")
# Out:
# ppae
# ppee
# pphe
# ppie
# pple
# ppne
# ppre
# 0.38485804416403785

# %%
ngrams
# Out:
# [{'a': 179837,
#   's': 148462,
#   'c': 89367,
#   'h': 58051,
#   'e': 233745,
#   'n': 152259,
#   'g': 51850,
#   'd': 74856,
#   'l': 122431,
#   'u': 77304,
#   'i': 184746,
#   't': 137277,
#   'm': 62191,
#   'o': 150052,
#   'p': 65785,
#   'r': 149228,
#   'v': 21057,
#   'k': 18685,
#   'w': 17732,
#   'f': 26431,
#   'b': 39840,
#   'x': 6050,
#   'y': 40985,
#   'j': 3790,
#   'z': 8749,
#   'q': 3986},
#  {'aa': 270,
#   'as': 10554,
#   'ac': 10476,
#   'ch': 12023,
#   'he': 11707,
#   'en': 23199,
#   'ae': 3350,
#   'ee': 5426,
#   'ag': 4914,
#   'ah': 1089,
#   'ed': 23098,
#   'hs': 600,
#   'al': 23550,
#   'le': 22135,
#   'es': 27128,
#   'su': 5905,
#   'un': 15154,
#   'nd': 9759,
#   'li': 19202,
#   'ii': 421,
#   'is': 20485,
#   'ls': 2019,
#   'st': 20183,
#   'am': 6969,
#   'an': 25117,
#   'da': 5429,
#   'hl': 1069,
#   'ao': 256,
#   'ap': 6038,
#   'ps': 2219,
#   'ss': 12161,
#   'ar': 19848,
#   'ra': 20481,
#   'au': 3471,
#   'rd': 3773,
#   'dv': 270,
#   'va': 3060,
#   'rk': 1282,
#   'dw': 387,
#   'wo': 2508,
#   'ol': 10801,
#   'lf': 1849,
#   're': 24800,
#   'rg': 2254,
#   'gh': 2377,
#   'ri': 20879,
#   'ik': 1532,
#   'ka': 1749,
#   'ro': 18733,
#   'on': 27389,
#   'ni': 12951,
#   'ic': 20223,
#   'it': 14248,
#   'te': 26219,
#   'ns': 8382,
#   'sb': 523,
#   'bu': 3014,
#   'ur': 8776,
#   'rp': 2021,
#   'rr': 3609,
#   'hh': 109,
#   'sv': 317,
#   'vo': 1571,
#   'og': 5662,
#   'ge': 7326,
#   'el': 14123,
#   'up': 2942,
#   'av': 2413,
#   'vs': 58,
#   'so': 5481,
#   'ab': 7258,
#   'ba': 5416,
#   'bd': 250,
#   'de': 13954,
#   'eh': 1014,
#   'ca': 13089,
#   'ax': 751,
#   'xi': 1195,
#   'ci': 6429,
#   'in': 37762,
#   'na': 10908,
#   'at': 23611,
#   'ti': 27596,
#   'io': 12043,
#   'sc': 5533,
#   'cu': 4345,
#   'us': 11339,
#   'ck': 4537,
#   'co': 14169,
#   'ct': 5616,
#   'er': 39200,
#   'ia': 11742,
#   'll': 13583,
#   'ly': 11070,
#   'to': 12632,
#   'or': 17544,
#   'ul': 8026,
#   'lu': 3910,
#   'se': 13813,
#   'ad': 6110,
#   'dd': 1321,
#   'do': 5147,
#   'ng': 19217,
#   'go': 3049,
#   'di': 10976,
#   'af': 1383,
#   'ft': 926,
#   'ga': 4660,
#   'ai': 4512,
#   'il': 10630,
#   'la': 15234,
#   'ak': 2070,
#   'ie': 8301,
#   'lo': 11622,
#   'ne': 19584,
#   'mp': 3951,
#   'pe': 10209,
#   'rs': 6776,
#   'nm': 915,
#   'me': 11077,
#   'nt': 16960,
#   'et': 10786,
#   'pt': 2495,
#   'mb': 2630,
#   'bo': 4514,
#   'rt': 5494,
#   'dn': 944,
#   'em': 7347,
#   'ts': 3462,
#   'sg': 187,
#   'gi': 4788,
#   'sh': 7431,
#   'hi': 9035,
#   'sl': 2306,
#   'hm': 597,
#   'si': 11042,
#   'sk': 1291,
#   'ta': 12414,
#   'tr': 11607,
#   'tj': 50,
#   'jo': 756,
#   'ou': 11691,
#   'tt': 4181,
#   'oi': 3350,
#   'ir': 4851,
#   'tu': 4243,
#   'ue': 2259,
#   've': 10593,
#   'ay': 1884,
#   'ya': 1364,
#   'bb': 1076,
#   'cy': 1932,
#   'id': 8250,
#   'ye': 1380,
#   'be': 5974,
#   'ev': 2369,
#   'vi': 4942,
#   'ea': 10223,
#   'ey': 1592,
#   'ys': 2150,
#   'bi': 5052,
#   'ot': 7647,
#   'tc': 1246,
#   'tn': 474,
#   'nu': 1896,
#   'iu': 1318,
#   'sf': 333,
#   'fo': 3560,
#   'ip': 4121,
#   'ud': 2235,
#   'br': 4084,
#   'bl': 7122,
#   'ry': 4394,
#   'oa': 2326,
#   'by': 480,
#   'bc': 221,
#   'sa': 5684,
#   'cs': 607,
#   'rh': 1206,
#   'ha': 9559,
#   'ld': 2118,
#   'iv': 4713,
#   'om': 9412,
#   'mi': 10403,
#   'no': 11278,
#   'oc': 6101,
#   'oh': 702,
#   'hy': 4286,
#   'ec': 7706,
#   'my': 1516,
#   'op': 8175,
#   'po': 7255,
#   'os': 9039,
#   'py': 970,
#   'ov': 3831,
#   'du': 2147,
#   'uc': 2667,
#   'ce': 9023,
#   'lb': 669,
#   'eb': 2171,
#   'um': 4969,
#   'eg': 2617,
#   'ei': 2838,
#   'ig': 4548,
#   'lm': 967,
#   'mo': 7289,
#   'hu': 1953,
#   'ks': 1081,
#   'lt': 2329,
#   'ez': 315,
#   'zr': 14,
#   'eo': 3025,
#   'ok': 1318,
#   'ku': 379,
#   'ut': 5487,
#   'ep': 5034,
#   'pp': 2260,
#   'rc': 3388,
#   'cr': 4845,
#   'rf': 969,
#   'fa': 2623,
#   'rn': 2930,
#   'th': 10336,
#   'nc': 7683,
#   'tl': 2137,
#   'ru': 3813,
#   'tm': 587,
#   'eu': 2600,
#   'bf': 89,
#   'fm': 89,
#   'bh': 126,
#   'hc': 147,
#   'nr': 1144,
#   'ho': 8845,
#   'ib': 2691,
#   'gl': 3363,
#   'dj': 175,
#   'ja': 992,
#   'ih': 274,
#   'im': 4921,
#   'yn': 1449,
#   'gd': 117,
#   'gt': 215,
#   'oe': 1715,
#   'ny': 1129,
#   'ph': 8865,
#   'iq': 284,
#   'qu': 3857,
#   'ui': 2507,
#   'bj': 148,
#   'je': 735,
#   'ju': 901,
#   'dg': 734,
#   'bk': 24,
#   'kh': 359,
#   'az': 964,
#   'zi': 1367,
#   'aq': 204,
#   'ze': 3531,
#   'od': 4632,
#   'gs': 1013,
#   'ow': 3545,
#   'bm': 151,
#   'mh': 64,
#   'bn': 110,
#   'ki': 3100,
#   'rm': 3945,
#   'ma': 12059,
#   'lc': 923,
#   'sm': 4173,
#   'iz': 4479,
#   'ln': 642,
#   'ke': 5188,
#   'ux': 260,
#   'ty': 4137,
#   'nn': 2779,
#   'if': 3508,
#   'ug': 1661,
#   'ht': 1862,
#   'ds': 1733,
#   'tf': 528,
#   'ef': 2340,
#   'gr': 4455,
#   'eq': 526,
#   'uo': 586,
#   'ew': 1677,
#   'wr': 541,
#   'ox': 1120,
#   'bp': 122,
#   'pc': 122,
#   'ms': 1192,
#   'xa': 585,
#   'zo': 1037,
#   'dl': 1925,
#   'gm': 476,
#   'oo': 5115,
#   'uz': 188,
#   'zz': 342,
#   'bs': 897,
#   'sr': 210,
#   'za': 1421,
#   'lv': 786,
#   'rb': 1913,
#   'bt': 280,
#   'sq': 591,
#   'ua': 2908,
#   'sy': 1699,
#   'yr': 1146,
#   'ub': 3074,
#   'ek': 573,
#   'kr': 305,
#   'cc': 1423,
#   'uk': 360,
#   'fe': 3328,
#   'fu': 2299,
#   'bv': 79,
#   'bw': 54,
#   'wa': 3292,
#   'yd': 863,
#   'yi': 871,
#   'ob': 2774,
#   'mu': 2356,
#   'aj': 211,
#   'yc': 1320,
#   'yp': 2029,
#   'yg': 526,
#   'pn': 304,
#   'pu': 2223,
#   'pi': 6063,
#   'aw': 1345,
#   'ws': 461,
#   'cb': 28,
#   'gn': 1589,
#   'cl': 3169,
#   'mm': 2012,
#   'pa': 7313,
#   'pl': 4323,
#   'oy': 690,
#   'ix': 513,
#   'cd': 68,
#   'dc': 256,
#   'hr': 2505,
#   'ff': 2055,
#   'fi': 4404,
#   'yl': 2197,
#   'gy': 1106,
#   'rv': 1117,
#   'vu': 244,
#   'dy': 1164,
#   'dr': 3164,
#   'fy': 504,
#   'yt': 1301,
#   'xy': 405,
#   'tp': 308,
#   'nz': 346,
#   'lg': 544,
#   'lh': 221,
#   'lp': 950,
#   'cf': 34,
#   'cg': 32,
#   'gu': 2361,
#   'hk': 60,
#   'ex': 2888,
#   'xt': 685,
#   'ym': 1353,
#   'rl': 1999,
#   'sp': 5151,
#   'df': 321,
#   'dh': 383,
#   'dp': 190,
#   'pr': 8590,
#   'of': 1584,
#   'dt': 213,
#   'sn': 1509,
#   'kl': 809,
#   'km': 154,
#   'kn': 541,
#   'wi': 3092,
#   'wl': 387,
#   'kp': 111,
#   'kw': 216,
#   'cm': 75,
#   'cn': 151,
#   'kb': 205,
#   'cp': 51,
#   'cq': 113,
#   'fl': 2487,
#   'yx': 108,
#   'yo': 989,
#   'tg': 213,
#   'oz': 457,
#   'nl': 1073,
#   'hn': 627,
#   'cw': 22,
#   'cx': 2,
#   'xo': 408,
#   'we': 3228,
#   'wn': 997,
#   'zl': 145,
#   'xe': 638,
#   'rw': 581,
#   'fr': 2019,
#   'ko': 838,
#   'nv': 1114,
#   'ji': 267,
#   'uv': 268,
#   'dk': 43,
#   'dm': 448,
#   'ij': 106,
#   'vt': 13,
#   'dz': 37,
#   'zh': 23,
#   'oj': 121,
#   'nk': 1436,
#   'kt': 197,
#   'fb': 90,
#   'fc': 197,
#   'fd': 159,
#   'np': 1403,
#   'xm': 27,
#   'vy': 127,
#   'fg': 46,
#   'fp': 116,
#   'fs': 349,
#   'wt': 134,
#   'sw': 982,
#   'wh': 1065,
#   'tw': 1188,
#   'uu': 43,
#   'lw': 270,
#   'mn': 568,
#   'gb': 173,
#   'gc': 66,
#   'ej': 265,
#   'nf': 1941,
#   'gg': 1315,
#   'pm': 141,
#   'gp': 81,
#   'yz': 121,
#   'uf': 619,
#   'uj': 65,
#   'gw': 176,
#   'iy': 70,
#   'uh': 74,
#   'hq': 13,
#   'hv': 38,
#   'hw': 296,
#   'mf': 165,
#   'ml': 260,
#   'mw': 70,
#   'nh': 897,
#   'wm': 116,
#   'xp': 540,
#   'hb': 269,
#   'tk': 67,
#   'vr': 86,
#   'iw': 99,
#   'xl': 60,
#   'jc': 11,
#   'nj': 314,
#   'jm': 4,
#   'zg': 9,
#   'kc': 79,
#   'ky': 453,
#   'kk': 96,
#   'kv': 39,
#   'tv': 96,
#   'uq': 29,
#   'rq': 93,
#   'oq': 190,
#   'fz': 3,
#   'fh': 61,
#   'rj': 111,
#   'yf': 267,
#   'nq': 277,
#   'nw': 588,
#   'lj': 30,
#   'lk': 618,
#   'tz': 318,
#   'nb': 969,
#   'yw': 243,
#   'zv': 7,
#   'uy': 97,
#   'yh': 185,
#   'xu': 158,
#   'lq': 19,
#   'lr': 201,
#   'sd': 235,
#   'rz': 98,
#   'zc': 11,
#   'td': 171,
#   'mr': 123,
#   'lz': 47,
#   'hp': 140,
#   'mc': 226,
#   'md': 99,
#   'hg': 67,
#   'yv': 84,
#   'mt': 95,
#   'mv': 62,
#   'mz': 10,
#   'vk': 16,
#   'nx': 56,
#   'gk': 31,
#   'hf': 202,
#   'fw': 68,
#   'yb': 402,
#   'hd': 126,
#   'zy': 258,
#   'wy': 143,
#   'pd': 84,
#   'pf': 123,
#   'pg': 56,
#   'pj': 14,
#   'pk': 45,
#   'wk': 113,
#   'ql': 4,
#   'wu': 84,
#   'sj': 47,
#   'kd': 60,
#   'mg': 45,
#   'wb': 191,
#   'ww': 77,
#   'pb': 145,
#   'hj': 15,
#   'kj': 23,
#   'tb': 437,
#   'yu': 152,
#   'sz': 35,
#   'fk': 20,
#   'gz': 10,
#   'vc': 11,
#   'vd': 12,
#   'vg': 9,
#   'zu': 107,
#   'vl': 34,
#   'vm': 15,
#   'vn': 18,
#   'db': 369,
#   'wf': 114,
#   'wg': 42,
#   'xf': 37,
#   'xh': 118,
#   'xs': 71,
#   'xw': 25,
#   'zt': 17,
#   'kf': 161,
#   'kg': 38,
#   'zn': 16,
#   'gf': 103,
#   'jr': 7,
#   'xr': 16,
#   'wc': 104,
#   'hz': 10,
#   'wd': 181,
#   'yk': 72,
#   'qw': 4,
#   'bx': 3,
#   'dq': 8,
#   'jy': 8,
#   'zb': 23,
#   'zd': 13,
#   'xd': 15,
#   'zp': 12,
#   'bg': 48,
#   'jp': 3,
#   'gv': 18,
#   'jw': 2,
#   'pv': 17,
#   'vv': 28,
#   'xb': 35,
#   'jn': 13,
#   'uw': 27,
#   'zk': 19,
#   'zs': 23,
#   'mq': 5,
#   'wj': 5,
#   'wp': 73,
#   'wz': 14,
#   'mj': 19,
#   'mk': 28,
#   'xc': 350,
#   'xn': 11,
#   'fn': 40,
#   'yj': 15,
#   'qs': 10,
#   'gj': 21,
#   'zw': 17,
#   'bz': 6,
#   'lx': 7,
#   'pw': 124,
#   'yy': 24,
#   'cv': 16,
#   'gx': 1,
#   'fj': 20,
#   'vw': 3,
#   'tq': 16,
#   'zm': 23,
#   'wv': 12,
#   'cz': 37,
#   'qa': 20,
#   'qn': 3,
#   'zf': 5,
#   'js': 10,
#   'qd': 3,
#   'sx': 5,
#   'cj': 1,
#   'dx': 4,
#   'vx': 1,
#   'vz': 3,
#   'xg': 9,
#   'xk': 2,
#   'xq': 6,
#   'xv': 5,
#   'xz': 1,
#   'qi': 11,
#   'jd': 8,
#   'fv': 18,
#   'fx': 3,
#   'jl': 4,
#   'gq': 2,
#   'rx': 10,
#   'jj': 6,
#   'fq': 6,
#   'pz': 1,
#   'px': 2,
#   'qr': 4,
#   'vb': 3,
#   'vp': 7,
#   'kq': 3,
#   'jb': 2,
#   'jf': 3,
#   'jg': 3,
#   'jh': 5,
#   'vh': 4,
#   'mx': 4,
#   'jt': 2,
#   'jv': 1,
#   'kx': 1,
#   'jk': 9,
#   'qc': 4,
#   'wq': 1,
#   'kz': 2,
#   'zq': 2,
#   'tx': 5,
#   'zj': 1,
#   'qt': 5,
#   'xx': 7,
#   'yq': 7,
#   'qg': 1,
#   'xj': 3,
#   'qb': 1,
#   'qe': 5,
#   'qf': 3,
#   'qh': 1,
#   'qk': 1,
#   'qm': 3,
#   'qo': 3,
#   'qp': 1,
#   'qq': 4,
#   'qv': 2,
#   'bq': 5,
#   'hx': 1,
#   'pq': 1,
#   'vf': 4,
#   'vj': 1},
#  {'aaa': 8,
#   'aas': 18,
#   'aac': 6,
#   'ach': 1469,
#   'che': 2342,
#   'hen': 898,
#   'aae': 3,
#   'aee': 9,
#   'aag': 9,
#   'aah': 4,
#   'ahe': 115,
#   'hed': 967,
#   'ahs': 78,
#   'aal': 42,
#   'ale': 1452,
#   'les': 2703,
#   'esu': 262,
#   'sun': 237,
#   'und': 2436,
#   'ali': 3714,
#   'lii': 33,
#   'iis': 18,
#   'als': 470,
#   'lst': 141,
#   'aam': 26,
#   'aan': 29,
#   'and': 2651,
#   'nda': 774,
#   'dah': 59,
#   'ahl': 35,
#   'aao': 1,
#   'aap': 5,
#   'aps': 262,
#   'pss': 5,
#   'aar': 39,
#   'ara': 1633,
#   'rau': 209,
#   'ard': 1887,
#   'rdv': 14,
#   'dva': 52,
#   'var': 331,
#   'ark': 509,
#   'rdw': 36,
#   'dwo': 86,
#   'wol': 100,
#   'olf': 90,
#   'are': 1221,
#   'ren': 1379,
#   'arg': 568,
#   'rgh': 47,
#   'ari': 3006,
#   'rik': 107,
#   'ika': 101,
#   'aro': 663,
#   'ron': 1649,
#   'oni': 3077,
#   'nic': 1924,
#   'nit': 1372,
#   'ite': 2985,
#   'ons': 2574,
#   'nsb': 41,
#   'sbu': 153,
#   'bur': 766,
#   'urg': 527,
#   'arp': 439,
#   'arr': 968,
#   'rrg': 3,
#   'ghh': 28,
#   'asv': 7,
#   'svo': 5,
#   'vog': 22,
#   'oge': 888,
#   'gel': 399,
#   'els': 362,
#   'aau': 7,
#   'aup': 59,
#   'aav': 1,
#   'avs': 8,
#   'vso': 2,
#   'aba': 398,
#   'bab': 185,
#   'abd': 81,
#   'bde': 54,
#   'deh': 103,
#   'bac': 711,
#   'aca': 499,
#   'cas': 587,
#   'cax': 5,
#   'axi': 303,
#   'aci': 867,
#   'cin': 1000,
#   'ina': 2388,
#   'nat': 2076,
#   'ati': 8072,
#   'tio': 6191,
#   'ion': 7691,
#   'cis': 539,
#   'isc': 947,
#   'scu': 467,
#   'cus': 441,
#   'ack': 1381,
#   'aco': 616,
#   'act': 1480,
#   'cte': 570,
#   'ter': 7912,
#   'eri': 4050,
#   'ria': 2288,
#   'ial': 1986,
#   'cti': 2056,
#   'tin': 4341,
#   'nal': 1925,
#   'all': 4759,
#   'lly': 2846,
#   'cto': 905,
#   'tor': 2907,
#   'acu': 308,
#   'cul': 1569,
#   'ulu': 167,
#   'lus': 618,
#   'use': 873,
#   'ses': 1681,
#   'bad': 112,
#   'ada': 463,
#   'add': 382,
#   'ddo': 58,
#   'don': 699,
#   'ade': 1247,
#   'den': 1586,
#   'eng': 419,
#   'ngo': 362,
#   'adi': 988,
#   'dit': 648,
#   'baf': 17,
#   'aft': 338,
#   'bag': 144,
#   'aga': 427,
#   'gai': 110,
#   'ail': 799,
#   'bai': 125,
#   'ila': 651,
#   'lar': 1890,
#   'ais': 366,
#   'ise': 2006,
#   'sed': 1228,
#   'iss': 926,
#   'sse': 1686,
#   'bak': 77,
#   'aka': 172,
#   'kas': 99,
#   'bal': 704,
#   'ala': 1313,
#   'lat': 2884,
#   'lie': 827,
#   'ien': 719,
#   'ena': 976,
#   'ate': 6552,
#   'ted': 4118,
#   'alo': 868,
#   'lon': 787,
#   'one': 2481,
#   'nes': 6804,
#   'bam': 55,
#   'amp': 805,
#   'mpe': 667,
#   'per': 4369,
#   'ere': 3025,
#   'res': 3357,
#   'ban': 630,
#   'ana': 1356,
#   'ndo': 707,
#   'ned': 1497,
#   'nee': 285,
#   'ner': 1543,
#   'ers': 4492,
#   'onm': 221,
#   'nme': 290,
#   'men': 3097,
#   'ent': 6454,
#   'ane': 1132,
#   'net': 927,
#   'ani': 2363,
#   'ant': 4548,
#   'nte': 3429,
#   'tes': 1560,
#   'bap': 58,
#   'apt': 315,
#   'pti': 848,
#   'tis': 1697,
#   'ist': 4903,
#   'sto': 1985,
#   'ton': 1771,
#   'bar': 1002,
#   'ram': 1098,
#   'amb': 644,
#   'mbo': 367,
#   'ris': 1937,
#   'art': 1811,
#   'rti': 1204,
#   'tic': 5247,
#   'icu': 662,
#   'ula': 2154,
#   'bas': 511,
#   'ase': 746,
#   'edn': 658,
#   'dne': 837,
#   'ess': 8423,
#   'sem': 1151,
#   'eme': 1224,
#   'nts': 643,
#   'ser': 1298,
#   'asg': 12,
#   'sgi': 14,
#   'ash': 748,
#   'she': 1266,
#   'shi': 1554,
#   'hin': 1457,
#   'ing': 15154,
#   'shl': 233,
#   'hle': 271,
#   'ssl': 185,
#   'sly': 812,
#   'shm': 139,
#   'hme': 182,
#   'asi': 1357,
#   'sia': 775,
#   'ias': 498,
#   'sin': 1754,
#   'ask': 157,
#   'ass': 1503,
#   'ssi': 1513,
#   'sie': 341,
#   'ieh': 15,
#   'ast': 2637,
#   'sta': 2366,
#   'tar': 1257,
#   'str': 2791,
#   'tra': 3625,
#   'ral': 1604,
#   'bat': 568,
#   'ata': 1031,
#   'tag': 408,
#   'age': 1418,
#   'tem': 627,
#   'atj': 2,
#   'tjo': 9,
#   'jou': 90,
#   'our': 1013,
#   'urs': 420,
#   'ato': 2343,
#   'ats': 260,
#   'att': 966,
#   'tti': 706,
#   'tto': 371,
#   'toi': 306,
#   'oir': 94,
#   'irs': 200,
#   'ttu': 70,
#   'tue': 35,
#   'atu': 571,
#   'tur': 1560,
#   'ure': 1523,
#   'bav': 12,
#   'ave': 1008,
#   'bax': 10,
#   'xil': 93,
#   'ile': 1141,
#   'bay': 66,
#   'aya': 189,
#   'yah': 30,
#   'abb': 345,
#   'bba': 102,
#   'cie': 418,
#   'ies': 3065,
#   'acy': 165,
#   'sid': 611,
#   'ica': 4959,
#   'cal': 4430,
#   'aye': 242,
#   'bbe': 314,
#   'bes': 418,
#   'bev': 38,
#   'evi': 609,
#   'vil': 968,
#   'lea': 1144,
#   'ean': 845,
#   'ill': 3112,
#   'lli': 2092,
#   'lia': 1148,
#   'ian': 2854,
#   'bey': 38,
#   'eys': 148,
#   'yst': 619,
#   'ste': 3207,
#   'ede': 775,
#   'bbi': 229,
#   'bie': 172,
#   'bbo': 64,
#   'bog': 85,
#   'oga': 383,
#   'gad': 107,
#   'bot': 271,
#   'otc': 91,
#   'tci': 11,
#   'otn': 8,
#   'tnu': 15,
#   'nul': 219,
#   'ull': 852,
#   'liu': 106,
#   'ius': 223,
#   'ots': 213,
#   'tsf': 9,
#   'sfo': 71,
#   'for': 2094,
#   'ord': 840,
#   'tsh': 131,
#   'hip': 981,
#   'ips': 244,
#   'tsu': 55,
#   'ott': 665,
#   'tts': 67,
#   'tso': 82,
#   'son': 955,
#   'bou': 446,
#   'oud': 154,
#   'bbr': 36,
#   'bre': 663,
#   'rev': 566,
#   'via': 274,
#   'iat': 1128,
#   'tab': 1096,
#   'abl': 3607,
#   'ble': 4421,
#   'ory': 724,
#   'bro': 955,
#   'roa': 489,
#   'oac': 204,
#   'chm': 174,
#   'bby': 68,
#   'bye': 34,
#   'abc': 7,
#   'bci': 9,
#   'ssa': 580,
#   'bcs': 2,
#   'bda': 15,
#   'dal': 678,
#   'dar': 451,
#   'del': 738,
#   'der': 2939,
#   'erh': 293,
#   'rha': 257,
#   'hal': 1684,
#   'ald': 319,
#   'lde': 513,
#   'rit': 1593,
#   'des': 1254,
#   'est': 3398,
#   'bdi': 50,
#   'dic': 1046,
#   'cab': 308,
#   'cat': 2021,
#   'tiv': 2217,
#   'ive': 3243,
#   'die': 536,
#   'iel': 350,
#   'ito': 670,
#   'bdo': 70,
#   'dom': 581,
#   'ome': 2114,
#   'omi': 1198,
#   'min': 2535,
#   'ino': 1214,
#   'noc': 458,
#   'oca': 795,
#   'car': 1842,
#   'rdi': 754,
#   'dia': 1319,
#   'iac': 502,
#   'ocy': 333,
#   'cys': 193,
#   'sti': 3384,
#   'noh': 32,
#   'ohy': 105,
#   'hys': 387,
#   'rec': 1805,
#   'ect': 2367,
#   'tom': 1515,
#   'omy': 603,
#   'nop': 520,
#   'opo': 762,
#   'pos': 1214,
#   'ost': 1960,
#   'rio': 976,
#   'ior': 244,
#   'nos': 729,
#   'osc': 580,
#   'sco': 1223,
#   'cop': 915,
#   'opy': 238,
#   'nou': 687,
#   'ous': 5647,
#   'nov': 179,
#   'ova': 280,
#   'vag': 171,
#   'agi': 602,
#   'gin': 930,
#   'bdu': 47,
#   'duc': 565,
#   'uce': 201,
#   'cen': 1275,
#   'ens': 1449,
#   'uci': 307,
#   'uct': 463,
#   'ors': 961,
#   'dul': 324,
#   'ulb': 56,
#   'lba': 87,
#   'bah': 49,
#   'aha': 146,
#   'abe': 351,
#   'bea': 532,
#   'ear': 1559,
#   'beb': 35,
#   'ebi': 165,
#   'bec': 191,
#   'ece': 463,
#   'ced': 677,
#   'eda': 377,
#   'ans': 1384,
#   'riu': 304,
#   'ium': 937,
#   'ary': 1048,
#   'bed': 518,
#   'neg': 214,
#   'ego': 253,
#   'bei': 55,
#   'eig': 311,
#   'igh': 1339,
#   'bel': 738,
#   'ela': 978,
#   'ele': 2046,
#   'eli': 1931,
#   'lit': 2829,
#   'elm': 169,
#   'lmo': 183,
#   'mos': 449,
#   'sch': 752,
#   'chu': 371,
#   'hus': 279,
#   'osk': 49,
#   'sks': 32,
#   'elo': 701,
#   'nia': 1364,
#   'elt': 284,
#   'ltr': 246,
#   'tre': 1222,
#   'ree': 1489,
#   'ben': 524,
#   'end': 1683,
#   'ene': 3262,
#   'nez': 17,
#   'ezr': 4,
#   'zra': 7,
#   'beo': 11,
#   'eok': 8,
#   'oku': 33,
#   'kut': 22,
#   'uta': 390,
#   'bep': 41,
#   'epp': 97,
#   'ber': 1569,
#   'erc': 1304,
#   'rcr': 79,
#   'cro': 1458,
#   'rom': 1446,
#   'omb': 405,
#   'mby': 29,
#   'erd': 578,
#   'rda': 278,
#   'dav': 53,
#   'avi': 601,
#   'vin': 835,
#   'ine': 4634,
#   'rde': 606,
#   'dee': 264,
#   'een': 684,
#   'nsh': 362,
#   'hir': 401,
#   'ire': 945,
#   'rdo': 235,
#   'erf': 618,
#   'rfa': 130,
#   'fan': 245,
#   'ern': 1049,
#   'rna': 551,
#   'ath': 1603,
#   'thy': 558,
#   'rno': 167,
#   'non': 4188,
#   'err': 1166,
#   'rra': 506,
#   'ran': 2864,
#   'anc': 1857,
#   'nce': 2109,
#   'ncy': 516,
#   'ntl': 641,
#   'tly': 619,
#   'rat': 3145,
#   'ona': 2399,
#   'rro': 544,
#   'met': 1926,
#   'ete': 1628,
#   'ert': 1360,
#   'eru': 293,
#   'run': 369,
#   'unc': 1604,
#   'nca': 426,
#   'bet': 301,
#   'etm': 43,
#   'tme': 205,
#   'ett': 1105,
#   'tta': 446,
#   'tal': 1869,
#   'tte': 1680,
#   'beu': 11,
#   'eya': 57,
#   'yan': 351,
#   'ces': 794,
#   'abf': 6,
#   'bfa': 13,
#   'far': 308,
#   'rad': 945,
#   'bfm': 2,
#   'abh': 22,
#   'bhc': 3,
#   'bhe': 14,
#   'enr': 116,
#   'nry': 51,
#   'bhi': 10,
#   'nay': 37,
#   'bho': 30,
#   'hom': 560,
#   'nab': 571,
#   'hor': 1524,
#   'orr': 662,
#   'rre': 893,
#   'red': 3084,
#   'enc': 1735,
#   'rer': 792,
#   'rri': 801,
#   'rib': 507,
#   'ibl': 747,
#   'abi': 1121,
#   'bia': 385,
#   'tha': 841,
#   'har': 1551,
#   'bic': 275,
#   'ich': 840,
#   'chi': 2348,
#   'hit': 576,
#   'bid': 162,
#   'ida': 1487,
#   'dan': 548,
#   'idd': 282,
#   'dde': 373,
#   'ide': 2104,
#   'ded': 1396,
#   'idi': 1203,
#   'din': 1611,
#   'ngl': 1607,
#   'gly': 1120,
#   'idj': 6,
#   'dja': 25,
#   'jan': 99,
#   'ied': 725,
#   'iet': 272,
#   'ten': 1899,
#   'eti': 1517,
#   'neo': 328,
#   'eou': 665,
#   'tit': 876,
#   'big': 118,
#   'iga': 430,
#   'gae': 65,
#   'ael': 93,
#   'ils': 220,
#   'gal': 721,
#   'ige': 423,
#   'gei': 54,
#   'bih': 9,
#   'ihu': 30,
#   'bil': 1342,
#   'lao': 24,
#   'ili': 2470,
#   'lim': 571,
#   'ime': 883,
#   'iti': 2836,
#   'tie': 1092,
#   'lla': 1715,
#   'ily': 552,
#   'lyn': 143,
#   'yne': 227,
#   'bim': 47,
#   'mel': 823,
#   'lec': 975,
#   'ech': 653,
#   'bin': 556,
#   'ngd': 43,
#   'gdo': 41,
#   'ngt': 153,
#   'gto': 75,
#   'noe': 99,
#   'oem': 62,
#   'bio': 397,
#   'iog': 199,
#   'gen': 1796,
#   'ese': 743,
#   'esi': 1160,
#   'sis': 1528,
#   'eni': 1597,
#   'nis': 2098,
#   'eny': 152,
#   'iol': 553,
#   'olo': 2422,
#   'log': 2111,
#   'ogi': 1280,
#   'gic': 811,
#   'ios': 346,
#   'ose': 1336,
#   'iot': 345,
#   'oti': 957,
#   'otr': 454,
#   'tro': 2364,
#   'rop': 1993,
#   'oph': 2225,
#   'phy': 1319,
#   'biq': 21,
#   'iqu': 275,
#   'qui': 1247,
#   'uiu': 4,
#   'bir': 272,
#   'irr': 374,
#   'ita': 1432,
#   'tan': 1476,
#   'tat': 1693,
#   'bis': 255,
#   'isa': 781,
#   'sag': 192,
#   'ish': 2248,
#   'sha': 1162,
#   'hag': 405,
#   'bit': 576,
#   'tib': 327,
#   'ibi': 459,
#   'biu': 43,
#   'iur': 72,
#   'ret': 1450,
#   'abj': 23,
#   'bje': 97,
#   'jec': 219,
#   'ctn': 32,
#   'tne': 365,
#   'bjo': 9,
#   'joi': 123,
#   'oin': 594,
#   'int': 2760,
#   'bju': 36,
#   'jud': 174,
#   'udg': 164,
#   'dge': 500,
#   'ged': 718,
#   'udi': 417,
#   'jun': 138,
#   'nct': 332,
#   'jur': 128,
#   'ura': 1095,
#   'rem': 899,
#   'uri': 1278,
#   'rin': 3190,
#   'abk': 6,
#   'bka': 2,
#   'kar': 219,
#   'bkh': 4,
#   'kha': 132,
#   'has': 386,
#   'haz': 79,
#   'azi': 224,
#   'zia': 47,
#   'bla': 676,
#   'lac': 1075,
#   'cta': 490,
#   'laq': 15,
#   'aqu': 188,
#   'que': 949,
#   'uea': 56,
#   'eat': 1304,
#   'las': 1338,
#   'iou': 1161,
#   'ves': 522,
#   'lau': 337,
#   'aut': 704,
#   'laz': 107,
#   'aze': 204,
#   'leb': 310,
#   'ebo': 366,
#   'bod': 183,
#   'odi': 872,
#   'lee': 408,
#   'eez': 82,
#   'eze': 80,
#   'leg': 545,
#   'ega': 596,
#   'gat': 686,
#   'lem': 601,
#   'emi': 2071,
#   'ind': 1648,
#   'nde': 3067,
#   'len': 1934,
#   'lep': 424,
#   'eph': 793,
#   'pha': 1522,
#   'rou': 1857,
#   'eps': 165,
#   'psi': 314,
#   'ept': 702,
#   'ler': 1570,
#   'let': 1117,
#   'bli': 609,
#   'lin': 3770,
#   'ngs': 725,
#   'blo': 436,
#   'loc': 709,
#   'ock': 1011,
#   'low': 953,
#   'blu': 248,
#   'lud': 156,
#   'ude': 365,
#   'lue': 270,
#   'uen': 285,
#   'lut': 472,
#   'ute': 644,
#   'uti': 770,
#   'bly': 713,
#   'abm': 7,
#   'bmh': 1,
#   'mho': 23,
#   'bmo': 13,
#   'mod': 317,
#   'oda': 326,
#   'abn': 35,
#   'bna': 12,
#   'nak': 113,
#   'aki': 463,
#   'kis': 204,
#   'bne': 41,
#   'bno': 32,
#   'nor': 628,
#   'orm': 1255,
#   'rma': 1009,
#   'mal': 1022,
#   'alc': 425,
#   'lcy': 23,
#   'lis': 2114,
#   'ism': 2544,
#   'liz': 1142,
#   'ize': 2648,
#   'izi': 656,
#   'zin': 888,
#   'aln': 303,
#   'lne': 537,
#   'rmi': 770,
#   'mit': 837,
#   'rmo': 530,
#   'mou': 642,
#   'abo': 446,
#   'boa': 309,
#   'oar': 348,
#   'dag': 132,
#   'boc': 69,
#   'oco': 611,
#   'coc': 538,
#   'cke': 985,
#   'ket': 375,
#   'ode': 811,
#   'dem': 640,
#   'ado': 462,
#   'boh': 36,
#   'ohm': 22,
#   'boi': 124,
#   'oid': 1311,
#   'dea': 569,
#   'eau': 196,
#   'aux': 94,
#   'oit': 150,
#   'tea': 562,
#   'bol': 465,
#   'oli': 1766,
#   'her': 2646,
#   'nar': 902,
#   'sts': 588,
#   'niz': 871,
#   'zed': 827,
#   'oll': 1054,
#   'lae': 283,
#   'bom': 99,
#   'oma': 1799,
#   'mas': 718,
#   'asa': 263,
#   'sal': 873,
#   'asu': 179,
#   'sum': 292,
#   'sus': 253,
#   'usi': 600,
#   'ity': 2133,
#   'bon': 438,
#   'ong': 1092,
#   'onn': 401,
#   'nne': 986,
#   'nem': 396,
#   'bor': 685,
#   'ora': 1433,
#   'ori': 2111,
#   'rig': 693,
#   'igi': 327,
#   'orn': 856,
#   'rse': 796,
#   'ort': 1746,
#   'rte': 811,
#   'ici': 1477,
#   'cid': 525,
#   'tif': 600,
#   'ifa': 86,
#   'fac': 534,
#   'ven': 1471,
#   'rts': 210,
#   'rtu': 213,
#   'tus': 293,
#   'ote': 988,
#   'ouc': 195,
#   'uch': 392,
#   'hem': 858,
#   'oug': 504,
#   'ugh': 646,
#   'ght': 1345,
#   'oul': 337,
#   'uli': 625,
#   'lic': 1639,
#   'oun': 1398,
#   'ndi': 1552,
#   'nds': 396,
#   'out': 1679,
#   'utf': 80,
#   'tfa': 67,
#   'ace': 1903,
#   'uts': 338,
#   'ipp': 527,
#   'ppe': 788,
#   'ped': 982,
#   'tsl': 22,
#   'sle': 338,
#   'led': 1946,
#   'edg': 228,
#   'bov': 37,
#   'ove': 2926,
#   'vec': 61,
#   'eci': 612,
#   'cit': 624,
#   'vef': 18,
#   'efo': 270,
#   'fou': 268,
#   'veg': 49,
#   'egr': 362,
#   'gro': 531,
#   'nam': 466,
#   'ame': 1112,
#   'med': 920,
#   'veq': 3,
#   'equ': 516,
#   'quo': 122,
#   'uot': 53,
#   'tai': 665,
#   'air': 637,
#   'vew': 20,
#   'ewr': 53,
#   'wri': 196,
#   'itt': 770,
#   'box': 128,
#   'abp': 4,
#   'bpc': 1,
#   'abr': 210,
#   'bra': 1286,
#   'rac': 1862,
#   'cad': 233,
#   'dab': 255,
#   'hia': 528,
#   'rah': 164,
#   'ham': 565,
#   'ami': 1185,
#   'mid': 588,
#   'dae': 831,
#   'ams': 182,
#   'han': 1431,
#   'amo': 549,
#   'mso': 42,
#   'nch': 1295,
#   'ras': 960,
#   'sax': 42,
#   'sio': 1029,
#   'iom': 223,
#   'siv': 577,
#   'vel': 1142,
#   'ely': 1202,
#   'tol': 687,
#   'rax': 79,
#   'axa': 53,
#   'xas': 23,
#   'raz': 170,
#   'zit': 37,
#   'azo': 220,
#   'rea': 2132,
#   'eac': 487,
#   'eas': 800,
#   'reg': 611,
#   'ege': 302,
#   'eno': 1174,
#   'enu': 286,
#   'nun': 154,
#   'nci': 756,
#   'cia': 841,
#   'bri': 835,
#   'ric': 2565,
#   'ico': 1003,
#   'rid': 1044,
#   'idg': 154,
#   'dga': 27,
#   'gab': 167,
#   'gea': 232,
#   'eab': 390,
#   'edl': 647,
#   'dly': 719,
#   'gem': 191,
#   'ger': 1332,
#   'dgi': 92,
#   'dgm': 19,
#   'gme': 112,
#   'roc': 1227,
#   'com': 1804,
#   'rog': 757,
#   'roo': 927,
#   'ook': 523,
#   'ros': 1762,
#   'osi': 1309,
#   'rot': 1299,
#   'bru': 230,
#   'rup': 231,
#   'upt': 170,
#   'pte': 489,
#   'ptn': 15,
#   'ruz': 11,
#   'uzz': 86,
#   'zzi': 58,
#   'abs': 219,
#   'bsa': 20,
#   'sam': 202,
#   'sar': 495,
#   'rok': 127,
#   'oka': 112,
#   'oki': 243,
#   'kit': 152,
#   'bsc': 86,
#   'sca': 822,
#   'cam': 397,
#   'sce': 676,
#   'ssr': 17,
#   'sro': 33,
#   'oot': 796,
#   'sci': 558,
#   'isi': 1004,
#   'sas': 107,
#   'con': 3548,
#   'ond': 1223,
#   'nsa': 401,
#   'cou': 978,
#   'bse': 131,
#   'see': 338,
#   'sei': 161,
#   'eil': 144,
#   'sen': 992,
#   'nta': 1728,
#   'tee': 475,
#   'ees': 322,
#   'nti': 3163,
#   'tia': 980,
#   'ntm': 52,
#   'tmi': 47,
#   'ntn': 116,
#   'sey': 96,
#   'bsh': 15,
#   'bsi': 70,
#   'nth': 1104,
#   'the': 2988,
#   ...},
#  {'aaaa': 3,
#   'aaas': 1,
#   'aach': 1,
#   'ache': 304,
#   'chen': 117,
#   'aaee': 1,
#   'aahe': 1,
#   'ahed': 58,
#   'aahs': 1,
#   'aale': 5,
#   'ales': 239,
#   'lesu': 4,
#   'esun': 5,
#   'sund': 50,
#   'aali': 9,
#   'alii': 8,
#   'liis': 1,
#   'aals': 7,
#   'alst': 13,
#   'aand': 2,
#   'anda': 254,
#   'ndah': 7,
#   'dahl': 11,
#   'aaps': 2,
#   'apss': 2,
#   'aara': 5,
#   'arau': 20,
#   'aard': 6,
#   'ardv': 5,
#   'rdva': 3,
#   'dvar': 4,
#   'vark': 3,
#   'ardw': 20,
#   'rdwo': 15,
#   'dwol': 1,
#   'wolf': 48,
#   'aare': 2,
#   'aren': 151,
#   'aarg': 1,
#   'argh': 9,
#   'aari': 3,
#   'arik': 11,
#   'rika': 19,
#   'aaro': 3,
#   'aron': 90,
#   'roni': 255,
#   'onic': 593,
#   'onit': 202,
#   'nite': 455,
#   'rons': 83,
#   'onsb': 7,
#   'nsbu': 25,
#   'sbur': 135,
#   'burg': 253,
#   'aarp': 1,
#   'aarr': 1,
#   'arrg': 1,
#   'rrgh': 1,
#   'rghh': 1,
#   'aasv': 1,
#   'asvo': 1,
#   'svog': 1,
#   'voge': 7,
#   'ogel': 21,
#   'gels': 17,
#   'aaup': 1,
#   'aavs': 1,
#   'avso': 1,
#   'abab': 3,
#   'babd': 1,
#   'abde': 5,
#   'bdeh': 1,
#   'abac': 26,
#   'baca': 11,
#   'acas': 14,
#   'acax': 2,
#   'caxi': 3,
#   'baci': 41,
#   'acin': 144,
#   'cina': 134,
#   'inat': 777,
#   'nati': 686,
#   'atio': 3995,
#   'tion': 5818,
#   'acis': 37,
#   'cisc': 11,
#   'iscu': 70,
#   'scus': 41,
#   'back': 404,
#   'baco': 17,
#   'bact': 96,
#   'acte': 223,
#   'cter': 191,
#   'teri': 915,
#   'eria': 447,
#   'rial': 524,
#   'acti': 677,
#   'ctin': 302,
#   'tina': 226,
#   'inal': 328,
#   'nall': 243,
#   'ally': 2368,
#   'acto': 160,
#   'ctor': 399,
#   'bacu': 14,
#   'acul': 142,
#   'culu': 66,
#   'ulus': 71,
#   'acus': 32,
#   'cuse': 45,
#   'uses': 229,
#   'abad': 17,
#   'bada': 11,
#   'badd': 8,
#   'addo': 20,
#   'ddon': 7,
#   'bade': 12,
#   'aden': 203,
#   'deng': 8,
#   'engo': 16,
#   'badi': 18,
#   'adit': 52,
#   'dite': 121,
#   'abaf': 1,
#   'baft': 3,
#   'abag': 6,
#   'baga': 11,
#   'agai': 11,
#   'gail': 5,
#   'abai': 10,
#   'bail': 33,
#   'aila': 39,
#   'ilar': 76,
#   'lard': 58,
#   'bais': 13,
#   'aise': 100,
#   'ised': 436,
#   'aiss': 21,
#   'isse': 179,
#   'abak': 6,
#   'baka': 7,
#   'akas': 13,
#   'abal': 39,
#   'bala': 108,
#   'alat': 137,
#   'lati': 921,
#   'bali': 77,
#   'alie': 97,
#   'lien': 89,
#   'iena': 24,
#   'enat': 160,
#   'nate': 715,
#   'ated': 1564,
#   'balo': 29,
#   'alon': 93,
#   'lone': 87,
#   'ones': 253,
#   'abam': 6,
#   'bamp': 2,
#   'ampe': 121,
#   'mper': 315,
#   'pere': 262,
#   'eres': 256,
#   'aban': 59,
#   'bana': 29,
#   'band': 199,
#   'ando': 142,
#   'ndon': 60,
#   'done': 69,
#   'oned': 349,
#   'onee': 40,
#   'oner': 230,
#   'ners': 188,
#   'donm': 4,
#   'onme': 69,
#   'nmen': 138,
#   'ment': 1905,
#   'dons': 15,
#   'bane': 36,
#   'anet': 69,
#   'bani': 55,
#   'anic': 266,
#   'bant': 43,
#   'ante': 394,
#   'ntes': 147,
#   'abap': 8,
#   'bapt': 40,
#   'apti': 108,
#   'ptis': 38,
#   'tist': 293,
#   'isto': 309,
#   'ston': 368,
#   'abar': 32,
#   'bara': 45,
#   'aram': 87,
#   'ramb': 67,
#   'ambo': 91,
#   'bari': 82,
#   'aris': 391,
#   'bart': 58,
#   'arti': 407,
#   'rtic': 245,
#   'ticu': 196,
#   'icul': 528,
#   'cula': 795,
#   'ular': 783,
#   'abas': 74,
#   'base': 78,
#   'ased': 78,
#   'sedn': 35,
#   'edne': 647,
#   'dnes': 795,
#   'ness': 5531,
#   'asem': 41,
#   'seme': 112,
#   'emen': 742,
#   'ents': 347,
#   'aser': 53,
#   'sers': 102,
#   'basg': 1,
#   'asgi': 3,
#   'bash': 45,
#   'ashe': 163,
#   'shed': 261,
#   'hedn': 25,
#   'ashi': 177,
#   'shin': 294,
#   'hing': 618,
#   'ashl': 34,
#   'shle': 28,
#   'hles': 83,
#   'less': 1322,
#   'essl': 129,
#   'ssly': 112,
#   'ashm': 21,
#   'shme': 79,
#   'hmen': 135,
#   'basi': 131,
#   'asia': 175,
#   'sias': 68,
#   'asin': 128,
#   'sing': 1008,
#   'bask': 26,
#   'bass': 66,
#   'assi': 406,
#   'ssie': 63,
#   'sieh': 2,
#   'bast': 70,
#   'asta': 147,
#   'star': 254,
#   'tard': 77,
#   'astr': 409,
#   'stra': 872,
#   'tral': 239,
#   'abat': 45,
#   'bata': 27,
#   'atag': 31,
#   'tage': 182,
#   'bate': 108,
#   'atem': 43,
#   'teme': 59,
#   'ater': 650,
#   'ters': 718,
#   'bati': 119,
#   'atic': 773,
#   'atis': 286,
#   'tise': 175,
#   'ises': 189,
#   'batj': 1,
#   'atjo': 1,
#   'tjou': 2,
#   'jour': 51,
#   'ours': 94,
#   'bato': 35,
#   'ator': 1193,
#   'bats': 8,
#   'batt': 99,
#   'atti': 137,
#   'ttis': 62,
#   'atto': 63,
#   'ttoi': 14,
#   'toir': 19,
#   'oirs': 9,
#   'attu': 17,
#   'ttue': 3,
#   'batu': 9,
#   'atur': 359,
#   'ture': 528,
#   'abav': 1,
#   'bave': 3,
#   'abax': 2,
#   'baxi': 5,
#   'axil': 59,
#   'xile': 13,
#   'abay': 5,
#   'baya': 14,
#   'ayah': 5,
#   'abba': 62,
#   'bbac': 3,
#   'acie': 76,
#   'cies': 186,
#   'bacy': 3,
#   'bbai': 5,
#   'bbas': 10,
#   'asid': 74,
#   'ssid': 37,
#   'bbat': 26,
#   'tica': 1294,
#   'ical': 3296,
#   'bbay': 1,
#   'baye': 7,
#   'abbe': 74,
#   'bbes': 7,
#   'bess': 15,
#   'esse': 864,
#   'sses': 714,
#   'bbev': 2,
#   'bevi': 7,
#   'evil': 169,
#   'vile': 48,
#   'ilea': 31,
#   'lean': 152,
#   'vill': 729,
#   'illi': 520,
#   'llia': 146,
#   'lian': 347,
#   'bbey': 3,
#   'beys': 4,
#   'eyst': 10,
#   'yste': 181,
#   'sted': 331,
#   'tede': 13,
#   'abbi': 78,
#   'bbie': 49,
#   'abbo': 15,
#   'bbog': 1,
#   'boga': 9,
#   'ogad': 5,
#   'gada': 15,
#   'bbot': 9,
#   'botc': 13,
#   'otci': 2,
#   'tcie': 2,
#   'botn': 1,
#   'otnu': 1,
#   'tnul': 1,
#   'null': 36,
#   'ulli': 128,
#   'lliu': 15,
#   'lius': 23,
#   'bots': 12,
#   'otsf': 2,
#   'tsfo': 5,
#   'sfor': 49,
#   'ford': 139,
#   'otsh': 9,
#   'tshi': 57,
#   'ship': 737,
#   'hips': 76,
#   'otsu': 3,
#   'tsun': 8,
#   'bott': 83,
#   'otts': 15,
#   'ttso': 3,
#   'tson': 21,
#   'bbou': 2,
#   'boud': 5,
#   'abbr': 17,
#   'bbre': 15,
#   'brev': 34,
#   'revi': 150,
#   'evia': 46,
#   'viat': 81,
#   'iata': 34,
#   'atab': 111,
#   'tabl': 711,
#   'able': 2986,
#   'iate': 464,
#   'ates': 612,
#   'iati': 372,
#   'iato': 117,
#   'tory': 508,
#   'bbro': 9,
#   'broa': 96,
#   'roac': 78,
#   'oach': 99,
#   'achm': 40,
#   'chme': 65,
#   'abby': 15,
#   'bbye': 2,
#   'abci': 1,
#   'bcis': 1,
#   'ciss': 55,
#   'issa': 119,
#   'abcs': 1,
#   'abda': 6,
#   'bdal': 2,
#   'bdar': 1,
#   'dari': 86,
#   'aria': 654,
#   'bdel': 17,
#   'bder': 4,
#   'derh': 40,
#   'erha': 71,
#   'rhal': 8,
#   'hald': 17,
#   'alde': 97,
#   'lden': 75,
#   'deri': 218,
#   'erit': 329,
#   'rite': 400,
#   'bdes': 1,
#   'dest': 186,
#   'abdi': 13,
#   'bdic': 12,
#   'dica': 336,
#   'icab': 89,
#   'cabl': 117,
#   'icat': 929,
#   'cate': 549,
#   'cati': 693,
#   'ativ': 998,
#   'tive': 1887,
#   'bdie': 1,
#   'diel': 14,
#   'bdit': 4,
#   'dito': 52,
#   'itor': 227,
#   'abdo': 44,
#   'bdom': 42,
#   'dome': 96,
#   'omen': 239,
#   'domi': 119,
#   'omin': 301,
#   'mina': 580,
#   'nale': 55,
#   'nali': 462,
#   'alia': 225,
#   'nals': 30,
#   'mino': 191,
#   'inoc': 89,
#   'noca': 49,
#   'ocar': 232,
#   'card': 269,
#   'ardi': 398,
#   'rdia': 118,
#   'diac': 93,
#   'nocy': 25,
#   'ocys': 74,
#   'cyst': 190,
#   'ysti': 110,
#   'stic': 1492,
#   'inoh': 6,
#   'nohy': 11,
#   'ohys': 8,
#   'hyst': 70,
#   'ster': 1370,
#   'tere': 524,
#   'erec': 83,
#   'rect': 280,
#   'ecto': 468,
#   'ctom': 199,
#   'tomy': 348,
#   'inop': 75,
#   'nopo': 62,
#   'opos': 54,
#   'post': 586,
#   'oste': 424,
#   'erio': 292,
#   'rior': 99,
#   'inos': 135,
#   'nosc': 62,
#   'osco': 337,
#   'scop': 451,
#   'copy': 115,
#   'inou': 198,
#   'nous': 529,
#   'inov': 15,
#   'nova': 47,
#   'ovag': 8,
#   'vagi': 49,
#   'agin': 214,
#   'gina': 133,
#   'bdon': 1,
#   'abdu': 12,
#   'bduc': 16,
#   'duce': 95,
#   'ucen': 21,
#   'cens': 98,
#   'cent': 739,
#   'ente': 602,
#   'duci': 101,
#   'ucin': 92,
#   'cing': 326,
#   'duct': 231,
#   'ucte': 35,
#   'cted': 284,
#   'ucti': 256,
#   'ctio': 727,
#   'ucto': 43,
#   'tors': 324,
#   'bdul': 2,
#   'dulb': 1,
#   'ulba': 9,
#   'lbah': 2,
#   'baha': 11,
#   'abea': 13,
#   'bear': 197,
#   'abeb': 1,
#   'bebi': 4,
#   'abec': 14,
#   'bece': 5,
#   'eced': 50,
#   'ceda': 29,
#   'edar': 44,
#   'rian': 687,
#   'ians': 142,
#   'ariu': 98,
#   'rium': 235,
#   'dary': 24,
#   'abed': 10,
#   'bede': 32,
#   'bedn': 11,
#   'dneg': 2,
#   'nego': 35,
#   'abei': 4,
#   'beig': 4,
#   'eigh': 208,
#   'abel': 104,
#   'bela': 38,
#   'elar': 38,
#   'bele': 42,
#   'eles': 361,
#   'beli': 111,
#   'elia': 181,
#   'elit': 113,
#   'lite': 430,
#   'belm': 6,
#   'elmo': 17,
#   'lmos': 18,
#   'mosc': 25,
#   'osch': 47,
#   'schu': 31,
#   'chus': 58,
#   'mosk': 5,
#   'osks': 4,
#   'belo': 41,
#   'elon': 90,
#   'loni': 135,
#   'onia': 428,
#   'nian': 377,
#   'belt': 40,
#   'eltr': 9,
#   'ltre': 16,
#   'tree': 137,
#   'aben': 16,
#   'bend': 52,
#   'bene': 88,
#   'enez': 9,
#   'nezr': 1,
#   'ezra': 2,
#   'abeo': 1,
#   'beok': 1,
#   'eoku': 2,
#   'okut': 1,
#   'kuta': 7,
#   'abep': 1,
#   'bepp': 1,
#   'aber': 65,
#   'berc': 83,
#   'ercr': 62,
#   'rcro': 16,
#   'crom': 92,
#   'romb': 47,
#   'omby': 9,
#   'berd': 24,
#   'erda': 56,
#   'rdav': 2,
#   'davi': 24,
#   'avin': 120,
#   'vine': 108,
#   'erde': 148,
#   'rdee': 17,
#   'deen': 11,
#   'eens': 64,
#   'ensh': 43,
#   'nshi': 174,
#   'shir': 97,
#   'hire': 71,
#   'erdo': 99,
#   'rdon': 53,
#   'doni': 75,
#   'berf': 9,
#   'erfa': 72,
#   'rfan': 8,
#   'beri': 109,
#   'bern': 81,
#   'erna': 306,
#   'rnat': 122,
#   'nath': 138,
#   'athy': 124,
#   'erno': 100,
#   'rnon': 12,
#   'berr': 210,
#   'erra': 180,
#   'rran': 115,
#   'ranc': 462,
#   'ance': 814,
#   'ancy': 221,
#   'rant': 373,
#   'antl': 210,
#   'ntly': 437,
#   'rrat': 94,
#   'rate': 1056,
#   'rati': 1186,
#   'atin': 1289,
#   'ting': 2701,
#   'iona': 1092,
#   'onal': 997,
#   'erro': 154,
#   'rrom': 17,
#   'rome': 319,
#   'omet': 736,
#   'mete': 536,
#   'eter': 951,
#   'bert': 144,
#   'beru': 7,
#   'erun': 36,
#   'runc': 47,
#   'unca': 155,
#   'ncat': 56,
#   'cato': 182,
#   'abes': 18,
#   'abet': 59,
#   'betm': 1,
#   'etme': 8,
#   'tmen': 165,
#   'bett': 53,
#   'etta': 124,
#   'ttal': 47,
#   'ette': 505,
#   'tted': 305,
#   'tter': 721,
#   'etto': 64,
#   'ttor': 37,
#   'abeu': 2,
#   'abey': 5,
#   'beya': 4,
#   'eyan': 22,
#   'yanc': 28,
#   'nces': 279,
#   'abfa': 2,
#   'bfar': 1,
#   'fara': 32,
#   'arad': 101,
#   'abfm': 1,
#   'abhc': 1,
#   'abhe': 1,
#   'bhen': 1,
#   'henr': 21,
#   'enry': 17,
#   'abhi': 1,
#   'bhin': 2,
#   'hina': 68,
#   'inay': 3,
#   'naya': 6,
#   'abho': 12,
#   'bhom': 1,
#   'homi': 45,
#   'inab': 153,
#   'nabl': 338,
#   'bhor': 14,
#   'horr': 52,
#   'orre': 133,
#   'rred': 108,
#   'rren': 114,
#   'renc': 220,
#   'ence': 810,
#   'rent': 332,
#   'rrer': 29,
#   'orri': 112,
#   'rrib': 17,
#   'ribl': 22,
#   'ible': 523,
#   'hors': 138,
#   'abia': 54,
#   'biat': 13,
#   'iath': 24,
#   'atha': 123,
#   'thar': 90,
#   'abic': 45,
#   'bich': 12,
#   'ichi': 87,
#   'chit': 123,
#   'hite': 298,
#   'abid': 26,
#   'bida': 22,
#   'idan': 72,
#   'danc': 86,
#   'bidd': 32,
#   'idde': 90,
#   'dden': 117,
#   'bide': 24,
#   'ided': 109,
#   'ider': 238,
#   'ders': 416,
#   'bidi': 34,
#   'idin': 246,
#   'ding': 920,
#   'ingl': 1150,
#   'ngly': 931,
#   'bidj': 1,
#   'idja': 1,
#   'djan': 2,
#   'abie': 22,
#   'bied': 8,
#   'bien': 23,
#   'ienc': 161,
#   'bies': 50,
#   'biet': 10,
#   'iete': 25,
#   'eten': 109,
#   'tene': 278,
#   'ieti': 56,
#   'etin': 221,
#   'tine': 455,
#   'ineo': 37,
#   'neou': 112,
#   'eous': 632,
#   'etit': 74,
#   'tite': 148,
#   'abig': 4,
#   'biga': 18,
#   'igae': 6,
#   'gael': 10,
#   'igai': 1,
#   'ails': 83,
#   'igal': 28,
#   'gale': 67,
#   'bige': 18,
#   'igei': 1,
#   'abih': 2,
#   'bihu': 1,
#   'abil': 690,
#   'bila': 56,
#   'ilao': 3,
#   'bili': 1003,
#   'ilim': 12,
#   'lime': 102,
#   'imen': 227,
#   'ilit': 1082,
#   'liti': 503,
#   'itie': 497,
#   'ties': 657,
#   'bill': 166,
#   'illa': 521,
#   'bily': 10,
#   'ilyn': 10,
#   'lyne': 21,
#   'abim': 1,
#   'bime': 9,
#   'imel': 31,
#   'mele': 67,
#   'elec': 434,
#   'lech': 51,
#   'abin': 47,
#   'bing': 158,
#   'ingd': 24,
#   'ngdo': 23,
#   'gdon': 10,
#   'ingt': 85,
#   'ngto': 65,
#   'gton': 59,
#   'bino': 36,
#   'inoe': 12,
#   'noem': 6,
#   'abio': 45,
#   'biog': 43,
#   'ioge': 41,
#   'ogen': 693,
#   'gene': 507,
#   'enes': 1707,
#   'nese': 89,
#   'eses': 55,
#   'nesi': 208,
#   'esis': 351,
#   'sist': 196,
#   'enet': 221,
#   'neti': 297,
#   'etic': 681,
#   'geni': 365,
#   'enis': 156,
#   'nist': 687,
#   'geny': 43,
#   'biol': 71,
#   'iolo': 242,
#   'olog': 1595,
#   'logi': 1176,
#   'ogic': 628,
#   'gica': 483,
#   'call': 1598,
#   'bios': 50,
#   'iose': 37,
#   'oses': 174,
#   'biot': 55,
#   'ioti': 86,
#   'otic': 327,
#   'iotr': 41,
#   'otro': 231,
#   'trop': 606,
#   'roph': 572,
#   'ophy': 455,
#   'abiq': 1,
#   'biqu': 21,
#   'iqui': 86,
#   'quiu': 3,
#   'abir': 18,
#   'birr': 10,
#   'irri': 84,
#   'rrit': 80,
#   'rita': 144,
#   'itan': 203,
#   'tant': 333,
#   'itat': 408,
#   'tate': 455,
#   'tati': 843,
#   'abis': 34,
#   'bisa': 8,
#   'isag': 48,
#   'bish': 65,
#   'isha': 92,
#   'shag': 25,
#   'bist': 33,
#   'abit': 88,
#   'biti': 90,
#   'itib': 6,
#   'tibi': 90,
#   'abiu': 5,
#   'biur': 3,
#   'iure': 19,
#   'uret': 153,
#   'abje': 6,
#   'bjec': 95,
#   'ject': 215,
#   'ecti': 699,
#   'ctiv': 467,
#   'ectn': 14,
#   'ctne': 31,
#   'tnes': 301,
#   'abjo': 3,
#   'bjoi': 4,
#   'join': 108,
#   'oint': 229,
#   'abju': 14,
#   'bjud': 7,
#   'judg': 56,
#   'udge': 111,
#   'dged': 90,
#   'judi': 75,
#   'udic': 95,
#   'bjun': 5,
#   'junc': 56,
#   'unct': 185,
#   'ncti': 169,
#   'bjur': 15,
#   'jura': 27,
#   'urat': 232,
#   'ions': 898,
#   'jure': 29,
#   'urem': 27,
#   'reme': 221,
#   'urer': 91,
#   'rers': 131,
#   'juri': 40,
#   'urin': 249,
#   'ring': 1571,
#   'abka': 2,
#   'bkar': 1,
#   'kari': 19,
#   'abkh': 3,
#   'bkha': 4,
#   'khas': 7,
#   'hasi': 84,
#   'sian': 218,
#   'khaz': 4,
#   'hazi': 11,
#   'azia': 10,
#   'abla': 24,
#   'blac': 164,
#   'lact': 146,
#   'acta': 69,
#   'ctat': 92,
#   'blaq': 1,
#   'laqu': 15,
#   'aque': 68,
#   'quea': 50,
#   'ueat': 8,
#   'eate': 291,
#   'blas': 217,
#   'last': 554,
#   'asti': 639,
#   'stin': 510,
#   'blat': 47,
#   'late': 1146,
#   'atit': 97,
#   'titi': 243,
#   'itio': 494,
#   'tiou': 236,
#   'ious': 1141,
#   'ives': 128,
#   'blau': 5,
#   'laut': 22,
#   'blaz': 27,
#   'laze': 34,
#   'bleb': 38,
#   'lebo': 71,
#   'ebod': 22,
#   'bodi': 91,
#   'odie': 97,
#   'died': 71,
#   'blee': 23,
#   'leez': 3,
#   'eeze': 51,
#   'bleg': 10,
#   'lega': 115,
#   'egat': 161,
#   'gate': 261,
#   'blem': 73,
#   'lemi': 78,
#   'emin': 279,
#   'mind': 205,
#   'inde': 468,
#   'nded': 494,
#   'blen': 688,
#   'lend': 126,
#   'blep': 57,
#   'leph': 90,
#   'epha': 425,
#   'phar': 196,
#   'hari': 156,
#   'haro': 71,
#   'arou': 84,
#   'rous': 1111,
#   'leps': 36,
#   'epsi': 73,
#   'psia': 38,
#   'lept': 95,
#   'epti': 270,
#   'ptic': 190,
#   'bler': 93,
#   'bles': 200,
#   'blet': 64,
#   'abli': 50,
#   'blin': 214,
#   'ling': 1697,
#   'ings': 599,
#   'ablo': 9,
#   'bloc': 65,
#   'lock': 249,
#   'blow': 82,
#   'ablu': 6,
#   'blud': 6,
#   'lude': 65,
#   'blue': 123,
#   'luen': 76,
#   'uent': 125,
#   'blut': 4,
#   'lute': 124,
#   'luti': 180,
#   'utio': 209,
#   'ably': 530,
#   'abmh': 1,
#   'bmho': 1,
#   'abmo': 1,
#   'bmod': 3,
#   'moda': 43,
#   'odal': 61,
#   'dali': 97,
#   'alit': 559,
#   'abna': 1,
#   'bnak': 1,
#   'naki': 20,
#   'akis': 37,
#   'abne': 20,
#   'bneg': 7,
#   'nega': 68,
#   'gati': 225,
#   'gato': 92,
#   'bner': 5,
#   'bnet': 4,
#   'abno': 13,
#   'bnor': 15,
#   'norm': 89,
#   'orma': 267,
#   'rmal': 155,
#   'malc': 19,
#   'alcy': 18,
#   'mali': 183,
#   'alis': 1080,
#   'lise': 256,
#   ...},
#  {'aaaaa': 2,
#   'aache': 1,
#   'achen': 10,
#   'aahed': 1,
#   'aales': 1,
#   'alesu': 2,
#   'lesun': 1,
#   'esund': 2,
#   'aalii': 1,
#   'aliis': 1,
#   'aalst': 1,
#   'aanda': 1,
#   'andah': 4,
#   'ndahl': 1,
#   'aapss': 1,
#   'aarau': 1,
#   'aardv': 1,
#   'ardva': 1,
#   'rdvar': 2,
#   'dvark': 2,
#   'aardw': 1,
#   'ardwo': 7,
#   'rdwol': 1,
#   'dwolf': 1,
#   'aaren': 1,
#   'aargh': 1,
#   'aarik': 1,
#   'arika': 3,
#   'aaron': 3,
#   'aroni': 16,
#   'ronic': 82,
#   'ronit': 17,
#   'onite': 95,
#   'arons': 4,
#   'ronsb': 1,
#   'onsbu': 7,
#   'nsbur': 24,
#   'sburg': 110,
#   'aarrg': 1,
#   'arrgh': 1,
#   'rrghh': 1,
#   'aasvo': 1,
#   'asvog': 1,
#   'svoge': 1,
#   'vogel': 4,
#   'ogels': 1,
#   'aavso': 1,
#   'ababd': 1,
#   'babde': 1,
#   'abdeh': 1,
#   'abaca': 3,
#   'bacas': 1,
#   'bacax': 1,
#   'acaxi': 1,
#   'abaci': 4,
#   'bacin': 2,
#   'acina': 12,
#   'cinat': 71,
#   'inati': 349,
#   'natio': 403,
#   'ation': 3945,
#   'bacis': 2,
#   'acisc': 1,
#   'ciscu': 2,
#   'iscus': 32,
#   'aback': 5,
#   'abaco': 3,
#   'abact': 3,
#   'bacte': 88,
#   'acter': 130,
#   'cteri': 122,
#   'teria': 166,
#   'erial': 158,
#   'bacti': 2,
#   'actin': 149,
#   'ctina': 24,
#   'tinal': 32,
#   'inall': 27,
#   'nally': 196,
#   'bacto': 1,
#   'actor': 93,
#   'abacu': 3,
#   'bacul': 9,
#   'aculu': 14,
#   'culus': 29,
#   'bacus': 2,
#   'acuse': 3,
#   'cuses': 18,
#   'abada': 2,
#   'abadd': 1,
#   'baddo': 1,
#   'addon': 4,
#   'abade': 1,
#   'baden': 5,
#   'adeng': 1,
#   'dengo': 1,
#   'abadi': 5,
#   'badit': 1,
#   'adite': 11,
#   'abaft': 1,
#   'abaga': 2,
#   'bagai': 1,
#   'agail': 1,
#   'abail': 1,
#   'baila': 5,
#   'ailar': 2,
#   'ilard': 2,
#   'abais': 5,
#   'baise': 1,
#   'aised': 26,
#   'baiss': 3,
#   'aisse': 8,
#   'abaka': 4,
#   'bakas': 1,
#   'abala': 8,
#   'balat': 6,
#   'alati': 48,
#   'latio': 399,
#   'abali': 12,
#   'balie': 2,
#   'alien': 39,
#   'liena': 19,
#   'ienat': 10,
#   'enate': 61,
#   'nated': 167,
#   'enati': 48,
#   'abalo': 4,
#   'balon': 6,
#   'alone': 19,
#   'lones': 14,
#   'abamp': 2,
#   'bampe': 1,
#   'amper': 62,
#   'mpere': 65,
#   'peres': 19,
#   'abana': 9,
#   'aband': 24,
#   'bando': 25,
#   'andon': 20,
#   'ndone': 15,
#   'doned': 7,
#   'donee': 2,
#   'doner': 6,
#   'oners': 41,
#   'ndonm': 3,
#   'donme': 3,
#   'onmen': 33,
#   'nment': 114,
#   'ndons': 1,
#   'abane': 4,
#   'banet': 1,
#   'abani': 5,
#   'banic': 1,
#   'abant': 5,
#   'bante': 9,
#   'antes': 35,
#   'abapt': 7,
#   'bapti': 37,
#   'aptis': 28,
#   'ptist': 18,
#   'tisto': 8,
#   'iston': 24,
#   'abara': 6,
#   'baram': 3,
#   'aramb': 5,
#   'rambo': 9,
#   'abari': 7,
#   'baris': 12,
#   'abart': 1,
#   'barti': 8,
#   'artic': 126,
#   'rticu': 91,
#   'ticul': 176,
#   'icula': 325,
#   'cular': 365,
#   'abase': 12,
#   'based': 8,
#   'asedn': 4,
#   'sedne': 34,
#   'ednes': 644,
#   'dness': 790,
#   'basem': 12,
#   'aseme': 17,
#   'semen': 77,
#   'ement': 620,
#   'ments': 223,
#   'baser': 3,
#   'asers': 15,
#   'abasg': 1,
#   'basgi': 1,
#   'abash': 11,
#   'bashe': 12,
#   'ashed': 55,
#   'shedn': 11,
#   'hedne': 25,
#   'bashi': 8,
#   'ashin': 56,
#   'shing': 201,
#   'bashl': 3,
#   'ashle': 10,
#   'shles': 10,
#   'hless': 77,
#   'lessl': 104,
#   'essly': 109,
#   'bashm': 2,
#   'ashme': 9,
#   'shmen': 71,
#   'hment': 104,
#   'abasi': 15,
#   'basia': 6,
#   'asias': 7,
#   'basin': 15,
#   'asing': 66,
#   'abask': 2,
#   'abass': 10,
#   'bassi': 11,
#   'assie': 25,
#   'ssieh': 2,
#   'abast': 8,
#   'basta': 19,
#   'astar': 23,
#   'stard': 30,
#   'bastr': 9,
#   'astra': 65,
#   'stral': 73,
#   'abata': 3,
#   'batag': 2,
#   'atage': 10,
#   'abate': 6,
#   'bated': 25,
#   'batem': 5,
#   'ateme': 20,
#   'temen': 41,
#   'bater': 8,
#   'aters': 74,
#   'abati': 13,
#   'batic': 23,
#   'batis': 9,
#   'atise': 42,
#   'tises': 25,
#   'abatj': 1,
#   'batjo': 1,
#   'atjou': 1,
#   'tjour': 2,
#   'jours': 1,
#   'abato': 4,
#   'bator': 14,
#   'abats': 1,
#   'abatt': 7,
#   'batti': 12,
#   'attis': 12,
#   'ttise': 3,
#   'batto': 7,
#   'attoi': 6,
#   'ttoir': 4,
#   'toirs': 2,
#   'battu': 6,
#   'attue': 2,
#   'abatu': 1,
#   'batur': 2,
#   'ature': 158,
#   'abave': 1,
#   'abaxi': 2,
#   'baxil': 2,
#   'axile': 5,
#   'abaya': 3,
#   'bayah': 1,
#   'abbac': 2,
#   'bbaci': 1,
#   'bacie': 2,
#   'acies': 43,
#   'bbacy': 1,
#   'abbai': 3,
#   'abbas': 5,
#   'bbasi': 2,
#   'basid': 18,
#   'bbass': 2,
#   'assid': 17,
#   'abbat': 25,
#   'bbate': 2,
#   'bbati': 11,
#   'atica': 240,
#   'tical': 1133,
#   'abbay': 1,
#   'bbaye': 1,
#   'abbes': 3,
#   'bbess': 1,
#   'besse': 9,
#   'esses': 559,
#   'abbev': 2,
#   'bbevi': 2,
#   'bevil': 3,
#   'evile': 9,
#   'vilea': 2,
#   'ilean': 9,
#   'evill': 76,
#   'villi': 27,
#   'illia': 53,
#   'llian': 64,
#   'abbey': 3,
#   'bbeys': 2,
#   'beyst': 1,
#   'eyste': 3,
#   'ysted': 7,
#   'stede': 2,
#   'abbie': 11,
#   'abbog': 1,
#   'bboga': 1,
#   'bogad': 2,
#   'ogada': 2,
#   'abbot': 9,
#   'bbotc': 1,
#   'botci': 1,
#   'otcie': 1,
#   'tcies': 2,
#   'bbotn': 1,
#   'botnu': 1,
#   'otnul': 1,
#   'tnull': 1,
#   'nulli': 23,
#   'ulliu': 1,
#   'llius': 2,
#   'bbots': 5,
#   'botsf': 1,
#   'otsfo': 1,
#   'tsfor': 2,
#   'sford': 15,
#   'botsh': 1,
#   'otshi': 1,
#   'tship': 43,
#   'ships': 60,
#   'botsu': 1,
#   'otsun': 1,
#   'bbott': 1,
#   'botts': 2,
#   'ottso': 1,
#   'ttson': 2,
#   'abbou': 1,
#   'bboud': 1,
#   'abbre': 10,
#   'bbrev': 9,
#   'brevi': 26,
#   'revia': 12,
#   'eviat': 32,
#   'viata': 1,
#   'iatab': 1,
#   'atabl': 71,
#   'table': 566,
#   'viate': 34,
#   'iated': 129,
#   'iates': 48,
#   'viati': 28,
#   'iatio': 180,
#   'viato': 14,
#   'iator': 87,
#   'atory': 351,
#   'abbro': 6,
#   'bbroa': 1,
#   'broac': 9,
#   'roach': 56,
#   'oachm': 9,
#   'achme': 22,
#   'chmen': 53,
#   'abbye': 1,
#   'abcis': 1,
#   'bciss': 1,
#   'cissa': 6,
#   'abdal': 2,
#   'abdar': 1,
#   'bdari': 1,
#   'daria': 19,
#   'abdel': 1,
#   'abder': 2,
#   'bderh': 1,
#   'derha': 8,
#   'erhal': 3,
#   'rhald': 1,
#   'halde': 9,
#   'alden': 7,
#   'bderi': 2,
#   'derit': 15,
#   'erite': 123,
#   'abdes': 1,
#   'bdest': 1,
#   'abdic': 8,
#   'bdica': 8,
#   'dicab': 22,
#   'icabl': 69,
#   'cable': 85,
#   'dicat': 145,
#   'icate': 288,
#   'cates': 44,
#   'icati': 500,
#   'catio': 467,
#   'cativ': 104,
#   'ative': 957,
#   'abdie': 1,
#   'bdiel': 1,
#   'abdit': 3,
#   'bdito': 1,
#   'ditor': 41,
#   'itory': 40,
#   'abdom': 30,
#   'bdome': 5,
#   'domen': 8,
#   'bdomi': 22,
#   'domin': 81,
#   'omina': 123,
#   'minal': 85,
#   'inale': 9,
#   'nales': 20,
#   'inali': 50,
#   'nalia': 18,
#   'alian': 89,
#   'inals': 10,
#   'omino': 21,
#   'minoc': 5,
#   'inoca': 6,
#   'nocar': 33,
#   'ocard': 51,
#   'cardi': 198,
#   'ardia': 86,
#   'rdiac': 27,
#   'inocy': 6,
#   'nocys': 6,
#   'ocyst': 74,
#   'cysti': 58,
#   'ystic': 56,
#   'minoh': 2,
#   'inohy': 3,
#   'nohys': 1,
#   'ohyst': 8,
#   'hyste': 57,
#   'yster': 91,
#   'stere': 179,
#   'terec': 16,
#   'erect': 43,
#   'recto': 74,
#   'ectom': 184,
#   'ctomy': 107,
#   'minop': 12,
#   'inopo': 6,
#   'nopos': 1,
#   'opost': 8,
#   'poste': 69,
#   'oster': 136,
#   'steri': 202,
#   'terio': 132,
#   'erior': 68,
#   'minos': 17,
#   'inosc': 17,
#   'nosco': 41,
#   'oscop': 318,
#   'scopy': 82,
#   'minou': 48,
#   'inous': 193,
#   'minov': 2,
#   'inova': 4,
#   'novag': 1,
#   'ovagi': 6,
#   'vagin': 43,
#   'agina': 65,
#   'ginal': 43,
#   'abdon': 1,
#   'abduc': 10,
#   'bduce': 5,
#   'ducen': 4,
#   'ucens': 1,
#   'ucent': 9,
#   'cente': 126,
#   'entes': 35,
#   'bduci': 2,
#   'ducin': 50,
#   'ucing': 50,
#   'bduct': 9,
#   'ducte': 15,
#   'ucted': 30,
#   'ducti': 141,
#   'uctio': 110,
#   'ction': 700,
#   'ducto': 25,
#   'uctor': 35,
#   'ctors': 54,
#   'abdul': 2,
#   'bdulb': 1,
#   'dulba': 1,
#   'ulbah': 1,
#   'lbaha': 2,
#   'abear': 2,
#   'abebi': 1,
#   'abece': 5,
#   'beced': 4,
#   'eceda': 7,
#   'cedar': 15,
#   'edari': 5,
#   'arian': 337,
#   'rians': 37,
#   'dariu': 6,
#   'arium': 69,
#   'edary': 6,
#   'abede': 1,
#   'abedn': 1,
#   'bedne': 10,
#   'edneg': 1,
#   'dnego': 1,
#   'abeig': 1,
#   'beigh': 1,
#   'abela': 5,
#   'belar': 2,
#   'elard': 2,
#   'abele': 5,
#   'beles': 5,
#   'abeli': 13,
#   'belia': 10,
#   'elian': 55,
#   'belit': 10,
#   'elite': 41,
#   'abelm': 2,
#   'belmo': 4,
#   'elmos': 2,
#   'lmosc': 7,
#   'mosch': 5,
#   'oschu': 1,
#   'schus': 5,
#   'lmosk': 1,
#   'mosks': 1,
#   'abelo': 2,
#   'belon': 10,
#   'eloni': 20,
#   'lonia': 38,
#   'onian': 147,
#   'abelt': 1,
#   'beltr': 2,
#   'eltre': 2,
#   'ltree': 3,
#   'abend': 3,
#   'abene': 1,
#   'benez': 1,
#   'enezr': 1,
#   'nezra': 1,
#   'abeok': 1,
#   'beoku': 1,
#   'eokut': 1,
#   'okuta': 1,
#   'abepp': 1,
#   'aberc': 1,
#   'bercr': 1,
#   'ercro': 15,
#   'rcrom': 1,
#   'cromb': 2,
#   'romby': 1,
#   'aberd': 9,
#   'berda': 8,
#   'erdav': 1,
#   'rdavi': 1,
#   'davin': 2,
#   'avine': 17,
#   'berde': 2,
#   'erdee': 8,
#   'rdeen': 3,
#   'deens': 3,
#   'eensh': 5,
#   'enshi': 14,
#   'nshir': 10,
#   'shire': 47,
#   'berdo': 4,
#   'erdon': 10,
#   'rdoni': 11,
#   'donia': 27,
#   'aberf': 1,
#   'berfa': 1,
#   'erfan': 6,
#   'aberi': 2,
#   'beria': 18,
#   'abern': 10,
#   'berna': 33,
#   'ernat': 83,
#   'rnath': 2,
#   'nathy': 4,
#   'berno': 8,
#   'ernon': 8,
#   'aberr': 13,
#   'berra': 9,
#   'erran': 41,
#   'rranc': 7,
#   'rance': 142,
#   'rancy': 18,
#   'rrant': 43,
#   'rantl': 33,
#   'antly': 147,
#   'errat': 45,
#   'rrate': 29,
#   'rrati': 44,
#   'ratin': 199,
#   'ating': 1051,
#   'ratio': 535,
#   'tiona': 803,
#   'ional': 781,
#   'rativ': 208,
#   'berro': 1,
#   'errom': 11,
#   'rrome': 5,
#   'romet': 138,
#   'omete': 319,
#   'meter': 453,
#   'abert': 4,
#   'aberu': 2,
#   'berun': 2,
#   'erunc': 1,
#   'runca': 15,
#   'uncat': 33,
#   'ncato': 3,
#   'cator': 129,
#   'abess': 1,
#   'abetm': 1,
#   'betme': 1,
#   'etmen': 5,
#   'tment': 134,
#   'abett': 5,
#   'betta': 3,
#   'ettal': 4,
#   'bette': 30,
#   'etted': 54,
#   'etter': 141,
#   'tters': 72,
#   'betto': 4,
#   'ettor': 5,
#   'abeya': 2,
#   'beyan': 3,
#   'eyanc': 9,
#   'yance': 21,
#   'ances': 123,
#   'yancy': 3,
#   'abfar': 1,
#   'bfara': 1,
#   'farad': 20,
#   'abhen': 1,
#   'bhenr': 1,
#   'henry': 10,
#   'abhin': 1,
#   'bhina': 1,
#   'hinay': 2,
#   'inaya': 2,
#   'abhom': 1,
#   'bhomi': 1,
#   'homin': 16,
#   'minab': 36,
#   'inabl': 125,
#   'nable': 287,
#   'abhor': 11,
#   'bhorr': 10,
#   'horre': 9,
#   'orred': 3,
#   'orren': 17,
#   'rrenc': 17,
#   'rence': 77,
#   'ences': 103,
#   'rrent': 49,
#   'orrer': 4,
#   'horri': 18,
#   'orrib': 4,
#   'rribl': 9,
#   'rible': 17,
#   'bhors': 1,
#   'abiat': 8,
#   'biath': 2,
#   'iatha': 3,
#   'athar': 36,
#   'abich': 3,
#   'bichi': 1,
#   'ichit': 8,
#   'chite': 50,
#   'abida': 3,
#   'bidan': 1,
#   'idanc': 10,
#   'dance': 60,
#   'abidd': 2,
#   'bidde': 15,
#   'idden': 56,
#   'abide': 3,
#   'bided': 2,
#   'bider': 3,
#   'iders': 19,
#   'abidi': 10,
#   'bidin': 18,
#   'iding': 92,
#   'dingl': 80,
#   'ingly': 926,
#   'abidj': 1,
#   'bidja': 1,
#   'idjan': 1,
#   'abied': 3,
#   'abien': 3,
#   'bienc': 4,
#   'ience': 99,
#   'abies': 7,
#   'abiet': 6,
#   'biete': 1,
#   'ieten': 4,
#   'etene': 21,
#   'bieti': 5,
#   'ietin': 8,
#   'etine': 17,
#   'tineo': 3,
#   'ineou': 17,
#   'neous': 112,
#   'ietit': 3,
#   'etite': 14,
#   'abiga': 3,
#   'bigae': 1,
#   'igael': 1,
#   'bigai': 1,
#   'igail': 1,
#   'gails': 1,
#   'bigal': 2,
#   'igale': 4,
#   'abige': 1,
#   'bigei': 1,
#   'abihu': 1,
#   'abila': 6,
#   'bilao': 2,
#   'abili': 661,
#   'bilim': 7,
#   'ilime': 6,
#   'limen': 40,
#   'iment': 170,
#   'bilit': 851,
#   'iliti': 133,
#   'litie': 201,
#   'ities': 475,
#   'abill': 7,
#   'billa': 15,
#   'abily': 2,
#   'bilyn': 1,
#   'ilyne': 1,
#   'abime': 1,
#   'bimel': 1,
#   'imele': 5,
#   'melec': 5,
#   'elech': 10,
#   'abing': 3,
#   'bingd': 1,
#   'ingdo': 16,
#   'ngdon': 6,
#   'bingt': 2,
#   'ingto': 62,
#   'ngton': 56,
#   'abino': 7,
#   'binoe': 1,
#   'inoem': 1,
#   'abiog': 8,
#   'bioge': 18,
#   'iogen': 35,
#   'ogene': 228,
#   'genes': 140,
#   'enese': 16,
#   'neses': 14,
#   'enesi': 114,
#   'nesis': 121,
#   'esist': 60,
#   'genet': 121,
#   'eneti': 133,
#   'netic': 196,
#   'etica': 181,
#   'ogeni': 213,
#   'genis': 27,
#   'enist': 36,
#   'ogeny': 38,
#   'abiol': 4,
#   'biolo': 63,
#   'iolog': 226,
#   'ologi': 1017,
#   'logic': 602,
#   'ogica': 425,
#   'gical': 480,
#   'icall': 1420,
#   'cally': 1445,
#   'abios': 7,
#   'biose': 8,
#   'ioses': 6,
#   'abiot': 5,
#   'bioti': 29,
#   'iotic': 57,
#   'otica': 61,
#   'biotr': 2,
#   'iotro': 28,
#   'otrop': 207,
#   'troph': 259,
#   'rophy': 129,
#   'abiqu': 1,
#   'biqui': 15,
#   'iquiu': 1,
#   'abirr': 3,
#   'birri': 6,
#   'irrit': 30,
#   'rrita': 28,
#   'ritan': 36,
#   'itant': 55,
#   'ritat': 20,
#   'itate': 135,
#   'tated': 86,
#   'itati': 227,
#   'tatio': 472,
#   'abisa': 1,
#   'bisag': 2,
#   'abish': 5,
#   'bisha': 3,
#   'ishag': 1,
#   'abist': 1,
#   'bisto': 4,
#   'abiti': 5,
#   'bitib': 1,
#   'itibi': 2,
#   'abiur': 1,
#   'biure': 2,
#   'iuret': 15,
#   'abjec': 6,
#   'bject': 95,
#   'jecti': 119,
#   'ectio': 269,
#   'ectiv': 180,
#   'ctive': 348,
#   'jectn': 1,
#   'ectne': 14,
#   'ctnes': 30,
#   'tness': 301,
#   'abjoi': 1,
#   'bjoin': 4,
#   'joint': 59,
#   'abjud': 4,
#   'bjudg': 2,
#   'judge': 30,
#   'udged': 18,
#   'bjudi': 5,
#   'judic': 73,
#   'udica': 35,
#   'catin': 109,
#   'icato': 91,
#   'abjun': 2,
#   'bjunc': 5,
#   'junct': 49,
#   'uncti': 94,
#   'nctiv': 43,
#   'abjur': 8,
#   'bjura': 4,
#   'jurat': 13,
#   'urati': 91,
#   'tions': 718,
#   'bjure': 4,
#   'jurem': 2,
#   'ureme': 22,
#   'remen': 91,
#   'jurer': 6,
#   'urers': 22,
#   'bjuri': 1,
#   'jurin': 6,
#   'uring': 156,
#   'abkar': 1,
#   'bkari': 1,
#   'abkha': 3,
#   'bkhas': 2,
#   'khasi': 2,
#   'hasia': 23,
#   'asian': 37,
#   'bkhaz': 1,
#   'khazi': 1,
#   'hazia': 1,
#   'ablac': 2,
#   'blact': 2,
#   'lacta': 20,
#   'actat': 16,
#   'ctate': 27,
#   'ctati': 45,
#   'tatin': 68,
#   'ablaq': 1,
#   'blaqu': 1,
#   'laque': 14,
#   'aquea': 6,
#   'queat': 7,
#   'ueate': 2,
#   'ablas': 5,
#   'blast': 197,
#   'lasti': 227,
#   'astin': 115,
#   'ablat': 10,
#   'blate': 11,
#   'lates': 89,
#   'blati': 11,
#   'latit': 26,
#   'atiti': 37,
#   'titio': 107,
#   'itiou': 97,
#   'tious': 236,
#   'lativ': 133,
#   'tives': 53,
#   'ablau': 1,
#   'blaut': 2,
#   'ablaz': 1,
#   'blaze': 13,
#   'ableb': 4,
#   'blebo': 9,
#   'lebod': 5,
#   'ebodi': 18,
#   'bodie': 63,
#   'odied': 46,
#   'ablee': 3,
#   'bleez': 2,
#   'leeze': 2,
#   'ableg': 3,
#   'blega': 4,
#   'legat': 44,
#   'egate': 55,
#   'gates': 39,
#   'ablem': 10,
#   'blemi': 19,
#   'lemin': 26,
#   'emind': 42,
#   'minde': 167,
#   'inded': 182,
#   'ablen': 494,
#   'blend': 22,
#   'ablep': 11,
#   'bleph': 32,
#   'lepha': 49,
#   'ephar': 37,
#   'phari': 10,
#   'haria': 17,
#   'pharo': 26,
#   'harou': 1,
#   'arous': 66,
#   'bleps': 10,
#   'lepsi': 18,
#   'epsia': 16,
#   'blept': 1,
#   'lepti': 25,
#   'eptic': 68,
#   'ptica': 52,
#   'abler': 12,
#   'ables': 53,
#   'bless': 40,
#   'lesse': 35,
#   'ablet': 13,
#   'ablin': 14,
#   'bling': 111,
#   'lings': 116,
#   'abloc': 3,
#   'block': 57,
#   'ablow': 1,
#   'ablud': 1,
#   'blude': 1,
#   'ablue': 1,
#   'bluen': 4,
#   'luent': 33,
#   'uents': 5,
#   'ablut': 3,
#   'blute': 1,
#   'bluti': 2,
#   'lutio': 88,
#   'ution': 197,
#   'abmho': 1,
#   'abmod': 1,
#   'bmoda': 1,
#   'modal': 14,
#   'odali': 18,
#   'dalit': 18,
#   'aliti': 106,
#   'abnak': 1,
#   'bnaki': 1,
#   'nakis': 3,
#   'abneg': 7,
#   'bnega': 7,
#   'negat': 40,
#   'gated': 80,
#   'egati': 67,
#   'gatin': 52,
#   'gatio': 116,
#   'egato': 15,
#   'gator': 70,
#   'abner': 1,
#   'abnet': 1,
#   'abnor': 13,
#   'bnorm': 14,
#   'norma': 74,
#   'ormal': 100,
#   'rmalc': 2,
#   'malcy': 1,
#   'rmali': 60,
#   'malis': 34,
#   'alise': 167,
#   'lised': 91,
#   'alism': 283,
#   'malit': 32,
#   'maliz': 27,
#   'alize': 481,
#   'alizi': 128,
#   'lizin': 175,
#   'izing': 611,
#   'rmaln': 4,
#   'malne': 5,
#   'alnes': 270,
#   ...}]

# %%
ngrams[2]["xyz"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[32], line 1
# ----> 1 ngrams[2]["xyz"]
#
# KeyError: 'xyz'

# %% [markdown]
# It is a bit absurd how much faster this code is...

# %%
ngrams[2]
# Out:
# {'aaa': 8,
#  'aas': 18,
#  'aac': 6,
#  'ach': 1469,
#  'che': 2342,
#  'hen': 898,
#  'aae': 3,
#  'aee': 9,
#  'aag': 9,
#  'aah': 4,
#  'ahe': 115,
#  'hed': 967,
#  'ahs': 78,
#  'aal': 42,
#  'ale': 1452,
#  'les': 2703,
#  'esu': 262,
#  'sun': 237,
#  'und': 2436,
#  'ali': 3714,
#  'lii': 33,
#  'iis': 18,
#  'als': 470,
#  'lst': 141,
#  'aam': 26,
#  'aan': 29,
#  'and': 2651,
#  'nda': 774,
#  'dah': 59,
#  'ahl': 35,
#  'aao': 1,
#  'aap': 5,
#  'aps': 262,
#  'pss': 5,
#  'aar': 39,
#  'ara': 1633,
#  'rau': 209,
#  'ard': 1887,
#  'rdv': 14,
#  'dva': 52,
#  'var': 331,
#  'ark': 509,
#  'rdw': 36,
#  'dwo': 86,
#  'wol': 100,
#  'olf': 90,
#  'are': 1221,
#  'ren': 1379,
#  'arg': 568,
#  'rgh': 47,
#  'ari': 3006,
#  'rik': 107,
#  'ika': 101,
#  'aro': 663,
#  'ron': 1649,
#  'oni': 3077,
#  'nic': 1924,
#  'nit': 1372,
#  'ite': 2985,
#  'ons': 2574,
#  'nsb': 41,
#  'sbu': 153,
#  'bur': 766,
#  'urg': 527,
#  'arp': 439,
#  'arr': 968,
#  'rrg': 3,
#  'ghh': 28,
#  'asv': 7,
#  'svo': 5,
#  'vog': 22,
#  'oge': 888,
#  'gel': 399,
#  'els': 362,
#  'aau': 7,
#  'aup': 59,
#  'aav': 1,
#  'avs': 8,
#  'vso': 2,
#  'aba': 398,
#  'bab': 185,
#  'abd': 81,
#  'bde': 54,
#  'deh': 103,
#  'bac': 711,
#  'aca': 499,
#  'cas': 587,
#  'cax': 5,
#  'axi': 303,
#  'aci': 867,
#  'cin': 1000,
#  'ina': 2388,
#  'nat': 2076,
#  'ati': 8072,
#  'tio': 6191,
#  'ion': 7691,
#  'cis': 539,
#  'isc': 947,
#  'scu': 467,
#  'cus': 441,
#  'ack': 1381,
#  'aco': 616,
#  'act': 1480,
#  'cte': 570,
#  'ter': 7912,
#  'eri': 4050,
#  'ria': 2288,
#  'ial': 1986,
#  'cti': 2056,
#  'tin': 4341,
#  'nal': 1925,
#  'all': 4759,
#  'lly': 2846,
#  'cto': 905,
#  'tor': 2907,
#  'acu': 308,
#  'cul': 1569,
#  'ulu': 167,
#  'lus': 618,
#  'use': 873,
#  'ses': 1681,
#  'bad': 112,
#  'ada': 463,
#  'add': 382,
#  'ddo': 58,
#  'don': 699,
#  'ade': 1247,
#  'den': 1586,
#  'eng': 419,
#  'ngo': 362,
#  'adi': 988,
#  'dit': 648,
#  'baf': 17,
#  'aft': 338,
#  'bag': 144,
#  'aga': 427,
#  'gai': 110,
#  'ail': 799,
#  'bai': 125,
#  'ila': 651,
#  'lar': 1890,
#  'ais': 366,
#  'ise': 2006,
#  'sed': 1228,
#  'iss': 926,
#  'sse': 1686,
#  'bak': 77,
#  'aka': 172,
#  'kas': 99,
#  'bal': 704,
#  'ala': 1313,
#  'lat': 2884,
#  'lie': 827,
#  'ien': 719,
#  'ena': 976,
#  'ate': 6552,
#  'ted': 4118,
#  'alo': 868,
#  'lon': 787,
#  'one': 2481,
#  'nes': 6804,
#  'bam': 55,
#  'amp': 805,
#  'mpe': 667,
#  'per': 4369,
#  'ere': 3025,
#  'res': 3357,
#  'ban': 630,
#  'ana': 1356,
#  'ndo': 707,
#  'ned': 1497,
#  'nee': 285,
#  'ner': 1543,
#  'ers': 4492,
#  'onm': 221,
#  'nme': 290,
#  'men': 3097,
#  'ent': 6454,
#  'ane': 1132,
#  'net': 927,
#  'ani': 2363,
#  'ant': 4548,
#  'nte': 3429,
#  'tes': 1560,
#  'bap': 58,
#  'apt': 315,
#  'pti': 848,
#  'tis': 1697,
#  'ist': 4903,
#  'sto': 1985,
#  'ton': 1771,
#  'bar': 1002,
#  'ram': 1098,
#  'amb': 644,
#  'mbo': 367,
#  'ris': 1937,
#  'art': 1811,
#  'rti': 1204,
#  'tic': 5247,
#  'icu': 662,
#  'ula': 2154,
#  'bas': 511,
#  'ase': 746,
#  'edn': 658,
#  'dne': 837,
#  'ess': 8423,
#  'sem': 1151,
#  'eme': 1224,
#  'nts': 643,
#  'ser': 1298,
#  'asg': 12,
#  'sgi': 14,
#  'ash': 748,
#  'she': 1266,
#  'shi': 1554,
#  'hin': 1457,
#  'ing': 15154,
#  'shl': 233,
#  'hle': 271,
#  'ssl': 185,
#  'sly': 812,
#  'shm': 139,
#  'hme': 182,
#  'asi': 1357,
#  'sia': 775,
#  'ias': 498,
#  'sin': 1754,
#  'ask': 157,
#  'ass': 1503,
#  'ssi': 1513,
#  'sie': 341,
#  'ieh': 15,
#  'ast': 2637,
#  'sta': 2366,
#  'tar': 1257,
#  'str': 2791,
#  'tra': 3625,
#  'ral': 1604,
#  'bat': 568,
#  'ata': 1031,
#  'tag': 408,
#  'age': 1418,
#  'tem': 627,
#  'atj': 2,
#  'tjo': 9,
#  'jou': 90,
#  'our': 1013,
#  'urs': 420,
#  'ato': 2343,
#  'ats': 260,
#  'att': 966,
#  'tti': 706,
#  'tto': 371,
#  'toi': 306,
#  'oir': 94,
#  'irs': 200,
#  'ttu': 70,
#  'tue': 35,
#  'atu': 571,
#  'tur': 1560,
#  'ure': 1523,
#  'bav': 12,
#  'ave': 1008,
#  'bax': 10,
#  'xil': 93,
#  'ile': 1141,
#  'bay': 66,
#  'aya': 189,
#  'yah': 30,
#  'abb': 345,
#  'bba': 102,
#  'cie': 418,
#  'ies': 3065,
#  'acy': 165,
#  'sid': 611,
#  'ica': 4959,
#  'cal': 4430,
#  'aye': 242,
#  'bbe': 314,
#  'bes': 418,
#  'bev': 38,
#  'evi': 609,
#  'vil': 968,
#  'lea': 1144,
#  'ean': 845,
#  'ill': 3112,
#  'lli': 2092,
#  'lia': 1148,
#  'ian': 2854,
#  'bey': 38,
#  'eys': 148,
#  'yst': 619,
#  'ste': 3207,
#  'ede': 775,
#  'bbi': 229,
#  'bie': 172,
#  'bbo': 64,
#  'bog': 85,
#  'oga': 383,
#  'gad': 107,
#  'bot': 271,
#  'otc': 91,
#  'tci': 11,
#  'otn': 8,
#  'tnu': 15,
#  'nul': 219,
#  'ull': 852,
#  'liu': 106,
#  'ius': 223,
#  'ots': 213,
#  'tsf': 9,
#  'sfo': 71,
#  'for': 2094,
#  'ord': 840,
#  'tsh': 131,
#  'hip': 981,
#  'ips': 244,
#  'tsu': 55,
#  'ott': 665,
#  'tts': 67,
#  'tso': 82,
#  'son': 955,
#  'bou': 446,
#  'oud': 154,
#  'bbr': 36,
#  'bre': 663,
#  'rev': 566,
#  'via': 274,
#  'iat': 1128,
#  'tab': 1096,
#  'abl': 3607,
#  'ble': 4421,
#  'ory': 724,
#  'bro': 955,
#  'roa': 489,
#  'oac': 204,
#  'chm': 174,
#  'bby': 68,
#  'bye': 34,
#  'abc': 7,
#  'bci': 9,
#  'ssa': 580,
#  'bcs': 2,
#  'bda': 15,
#  'dal': 678,
#  'dar': 451,
#  'del': 738,
#  'der': 2939,
#  'erh': 293,
#  'rha': 257,
#  'hal': 1684,
#  'ald': 319,
#  'lde': 513,
#  'rit': 1593,
#  'des': 1254,
#  'est': 3398,
#  'bdi': 50,
#  'dic': 1046,
#  'cab': 308,
#  'cat': 2021,
#  'tiv': 2217,
#  'ive': 3243,
#  'die': 536,
#  'iel': 350,
#  'ito': 670,
#  'bdo': 70,
#  'dom': 581,
#  'ome': 2114,
#  'omi': 1198,
#  'min': 2535,
#  'ino': 1214,
#  'noc': 458,
#  'oca': 795,
#  'car': 1842,
#  'rdi': 754,
#  'dia': 1319,
#  'iac': 502,
#  'ocy': 333,
#  'cys': 193,
#  'sti': 3384,
#  'noh': 32,
#  'ohy': 105,
#  'hys': 387,
#  'rec': 1805,
#  'ect': 2367,
#  'tom': 1515,
#  'omy': 603,
#  'nop': 520,
#  'opo': 762,
#  'pos': 1214,
#  'ost': 1960,
#  'rio': 976,
#  'ior': 244,
#  'nos': 729,
#  'osc': 580,
#  'sco': 1223,
#  'cop': 915,
#  'opy': 238,
#  'nou': 687,
#  'ous': 5647,
#  'nov': 179,
#  'ova': 280,
#  'vag': 171,
#  'agi': 602,
#  'gin': 930,
#  'bdu': 47,
#  'duc': 565,
#  'uce': 201,
#  'cen': 1275,
#  'ens': 1449,
#  'uci': 307,
#  'uct': 463,
#  'ors': 961,
#  'dul': 324,
#  'ulb': 56,
#  'lba': 87,
#  'bah': 49,
#  'aha': 146,
#  'abe': 351,
#  'bea': 532,
#  'ear': 1559,
#  'beb': 35,
#  'ebi': 165,
#  'bec': 191,
#  'ece': 463,
#  'ced': 677,
#  'eda': 377,
#  'ans': 1384,
#  'riu': 304,
#  'ium': 937,
#  'ary': 1048,
#  'bed': 518,
#  'neg': 214,
#  'ego': 253,
#  'bei': 55,
#  'eig': 311,
#  'igh': 1339,
#  'bel': 738,
#  'ela': 978,
#  'ele': 2046,
#  'eli': 1931,
#  'lit': 2829,
#  'elm': 169,
#  'lmo': 183,
#  'mos': 449,
#  'sch': 752,
#  'chu': 371,
#  'hus': 279,
#  'osk': 49,
#  'sks': 32,
#  'elo': 701,
#  'nia': 1364,
#  'elt': 284,
#  'ltr': 246,
#  'tre': 1222,
#  'ree': 1489,
#  'ben': 524,
#  'end': 1683,
#  'ene': 3262,
#  'nez': 17,
#  'ezr': 4,
#  'zra': 7,
#  'beo': 11,
#  'eok': 8,
#  'oku': 33,
#  'kut': 22,
#  'uta': 390,
#  'bep': 41,
#  'epp': 97,
#  'ber': 1569,
#  'erc': 1304,
#  'rcr': 79,
#  'cro': 1458,
#  'rom': 1446,
#  'omb': 405,
#  'mby': 29,
#  'erd': 578,
#  'rda': 278,
#  'dav': 53,
#  'avi': 601,
#  'vin': 835,
#  'ine': 4634,
#  'rde': 606,
#  'dee': 264,
#  'een': 684,
#  'nsh': 362,
#  'hir': 401,
#  'ire': 945,
#  'rdo': 235,
#  'erf': 618,
#  'rfa': 130,
#  'fan': 245,
#  'ern': 1049,
#  'rna': 551,
#  'ath': 1603,
#  'thy': 558,
#  'rno': 167,
#  'non': 4188,
#  'err': 1166,
#  'rra': 506,
#  'ran': 2864,
#  'anc': 1857,
#  'nce': 2109,
#  'ncy': 516,
#  'ntl': 641,
#  'tly': 619,
#  'rat': 3145,
#  'ona': 2399,
#  'rro': 544,
#  'met': 1926,
#  'ete': 1628,
#  'ert': 1360,
#  'eru': 293,
#  'run': 369,
#  'unc': 1604,
#  'nca': 426,
#  'bet': 301,
#  'etm': 43,
#  'tme': 205,
#  'ett': 1105,
#  'tta': 446,
#  'tal': 1869,
#  'tte': 1680,
#  'beu': 11,
#  'eya': 57,
#  'yan': 351,
#  'ces': 794,
#  'abf': 6,
#  'bfa': 13,
#  'far': 308,
#  'rad': 945,
#  'bfm': 2,
#  'abh': 22,
#  'bhc': 3,
#  'bhe': 14,
#  'enr': 116,
#  'nry': 51,
#  'bhi': 10,
#  'nay': 37,
#  'bho': 30,
#  'hom': 560,
#  'nab': 571,
#  'hor': 1524,
#  'orr': 662,
#  'rre': 893,
#  'red': 3084,
#  'enc': 1735,
#  'rer': 792,
#  'rri': 801,
#  'rib': 507,
#  'ibl': 747,
#  'abi': 1121,
#  'bia': 385,
#  'tha': 841,
#  'har': 1551,
#  'bic': 275,
#  'ich': 840,
#  'chi': 2348,
#  'hit': 576,
#  'bid': 162,
#  'ida': 1487,
#  'dan': 548,
#  'idd': 282,
#  'dde': 373,
#  'ide': 2104,
#  'ded': 1396,
#  'idi': 1203,
#  'din': 1611,
#  'ngl': 1607,
#  'gly': 1120,
#  'idj': 6,
#  'dja': 25,
#  'jan': 99,
#  'ied': 725,
#  'iet': 272,
#  'ten': 1899,
#  'eti': 1517,
#  'neo': 328,
#  'eou': 665,
#  'tit': 876,
#  'big': 118,
#  'iga': 430,
#  'gae': 65,
#  'ael': 93,
#  'ils': 220,
#  'gal': 721,
#  'ige': 423,
#  'gei': 54,
#  'bih': 9,
#  'ihu': 30,
#  'bil': 1342,
#  'lao': 24,
#  'ili': 2470,
#  'lim': 571,
#  'ime': 883,
#  'iti': 2836,
#  'tie': 1092,
#  'lla': 1715,
#  'ily': 552,
#  'lyn': 143,
#  'yne': 227,
#  'bim': 47,
#  'mel': 823,
#  'lec': 975,
#  'ech': 653,
#  'bin': 556,
#  'ngd': 43,
#  'gdo': 41,
#  'ngt': 153,
#  'gto': 75,
#  'noe': 99,
#  'oem': 62,
#  'bio': 397,
#  'iog': 199,
#  'gen': 1796,
#  'ese': 743,
#  'esi': 1160,
#  'sis': 1528,
#  'eni': 1597,
#  'nis': 2098,
#  'eny': 152,
#  'iol': 553,
#  'olo': 2422,
#  'log': 2111,
#  'ogi': 1280,
#  'gic': 811,
#  'ios': 346,
#  'ose': 1336,
#  'iot': 345,
#  'oti': 957,
#  'otr': 454,
#  'tro': 2364,
#  'rop': 1993,
#  'oph': 2225,
#  'phy': 1319,
#  'biq': 21,
#  'iqu': 275,
#  'qui': 1247,
#  'uiu': 4,
#  'bir': 272,
#  'irr': 374,
#  'ita': 1432,
#  'tan': 1476,
#  'tat': 1693,
#  'bis': 255,
#  'isa': 781,
#  'sag': 192,
#  'ish': 2248,
#  'sha': 1162,
#  'hag': 405,
#  'bit': 576,
#  'tib': 327,
#  'ibi': 459,
#  'biu': 43,
#  'iur': 72,
#  'ret': 1450,
#  'abj': 23,
#  'bje': 97,
#  'jec': 219,
#  'ctn': 32,
#  'tne': 365,
#  'bjo': 9,
#  'joi': 123,
#  'oin': 594,
#  'int': 2760,
#  'bju': 36,
#  'jud': 174,
#  'udg': 164,
#  'dge': 500,
#  'ged': 718,
#  'udi': 417,
#  'jun': 138,
#  'nct': 332,
#  'jur': 128,
#  'ura': 1095,
#  'rem': 899,
#  'uri': 1278,
#  'rin': 3190,
#  'abk': 6,
#  'bka': 2,
#  'kar': 219,
#  'bkh': 4,
#  'kha': 132,
#  'has': 386,
#  'haz': 79,
#  'azi': 224,
#  'zia': 47,
#  'bla': 676,
#  'lac': 1075,
#  'cta': 490,
#  'laq': 15,
#  'aqu': 188,
#  'que': 949,
#  'uea': 56,
#  'eat': 1304,
#  'las': 1338,
#  'iou': 1161,
#  'ves': 522,
#  'lau': 337,
#  'aut': 704,
#  'laz': 107,
#  'aze': 204,
#  'leb': 310,
#  'ebo': 366,
#  'bod': 183,
#  'odi': 872,
#  'lee': 408,
#  'eez': 82,
#  'eze': 80,
#  'leg': 545,
#  'ega': 596,
#  'gat': 686,
#  'lem': 601,
#  'emi': 2071,
#  'ind': 1648,
#  'nde': 3067,
#  'len': 1934,
#  'lep': 424,
#  'eph': 793,
#  'pha': 1522,
#  'rou': 1857,
#  'eps': 165,
#  'psi': 314,
#  'ept': 702,
#  'ler': 1570,
#  'let': 1117,
#  'bli': 609,
#  'lin': 3770,
#  'ngs': 725,
#  'blo': 436,
#  'loc': 709,
#  'ock': 1011,
#  'low': 953,
#  'blu': 248,
#  'lud': 156,
#  'ude': 365,
#  'lue': 270,
#  'uen': 285,
#  'lut': 472,
#  'ute': 644,
#  'uti': 770,
#  'bly': 713,
#  'abm': 7,
#  'bmh': 1,
#  'mho': 23,
#  'bmo': 13,
#  'mod': 317,
#  'oda': 326,
#  'abn': 35,
#  'bna': 12,
#  'nak': 113,
#  'aki': 463,
#  'kis': 204,
#  'bne': 41,
#  'bno': 32,
#  'nor': 628,
#  'orm': 1255,
#  'rma': 1009,
#  'mal': 1022,
#  'alc': 425,
#  'lcy': 23,
#  'lis': 2114,
#  'ism': 2544,
#  'liz': 1142,
#  'ize': 2648,
#  'izi': 656,
#  'zin': 888,
#  'aln': 303,
#  'lne': 537,
#  'rmi': 770,
#  'mit': 837,
#  'rmo': 530,
#  'mou': 642,
#  'abo': 446,
#  'boa': 309,
#  'oar': 348,
#  'dag': 132,
#  'boc': 69,
#  'oco': 611,
#  'coc': 538,
#  'cke': 985,
#  'ket': 375,
#  'ode': 811,
#  'dem': 640,
#  'ado': 462,
#  'boh': 36,
#  'ohm': 22,
#  'boi': 124,
#  'oid': 1311,
#  'dea': 569,
#  'eau': 196,
#  'aux': 94,
#  'oit': 150,
#  'tea': 562,
#  'bol': 465,
#  'oli': 1766,
#  'her': 2646,
#  'nar': 902,
#  'sts': 588,
#  'niz': 871,
#  'zed': 827,
#  'oll': 1054,
#  'lae': 283,
#  'bom': 99,
#  'oma': 1799,
#  'mas': 718,
#  'asa': 263,
#  'sal': 873,
#  'asu': 179,
#  'sum': 292,
#  'sus': 253,
#  'usi': 600,
#  'ity': 2133,
#  'bon': 438,
#  'ong': 1092,
#  'onn': 401,
#  'nne': 986,
#  'nem': 396,
#  'bor': 685,
#  'ora': 1433,
#  'ori': 2111,
#  'rig': 693,
#  'igi': 327,
#  'orn': 856,
#  'rse': 796,
#  'ort': 1746,
#  'rte': 811,
#  'ici': 1477,
#  'cid': 525,
#  'tif': 600,
#  'ifa': 86,
#  'fac': 534,
#  'ven': 1471,
#  'rts': 210,
#  'rtu': 213,
#  'tus': 293,
#  'ote': 988,
#  'ouc': 195,
#  'uch': 392,
#  'hem': 858,
#  'oug': 504,
#  'ugh': 646,
#  'ght': 1345,
#  'oul': 337,
#  'uli': 625,
#  'lic': 1639,
#  'oun': 1398,
#  'ndi': 1552,
#  'nds': 396,
#  'out': 1679,
#  'utf': 80,
#  'tfa': 67,
#  'ace': 1903,
#  'uts': 338,
#  'ipp': 527,
#  'ppe': 788,
#  'ped': 982,
#  'tsl': 22,
#  'sle': 338,
#  'led': 1946,
#  'edg': 228,
#  'bov': 37,
#  'ove': 2926,
#  'vec': 61,
#  'eci': 612,
#  'cit': 624,
#  'vef': 18,
#  'efo': 270,
#  'fou': 268,
#  'veg': 49,
#  'egr': 362,
#  'gro': 531,
#  'nam': 466,
#  'ame': 1112,
#  'med': 920,
#  'veq': 3,
#  'equ': 516,
#  'quo': 122,
#  'uot': 53,
#  'tai': 665,
#  'air': 637,
#  'vew': 20,
#  'ewr': 53,
#  'wri': 196,
#  'itt': 770,
#  'box': 128,
#  'abp': 4,
#  'bpc': 1,
#  'abr': 210,
#  'bra': 1286,
#  'rac': 1862,
#  'cad': 233,
#  'dab': 255,
#  'hia': 528,
#  'rah': 164,
#  'ham': 565,
#  'ami': 1185,
#  'mid': 588,
#  'dae': 831,
#  'ams': 182,
#  'han': 1431,
#  'amo': 549,
#  'mso': 42,
#  'nch': 1295,
#  'ras': 960,
#  'sax': 42,
#  'sio': 1029,
#  'iom': 223,
#  'siv': 577,
#  'vel': 1142,
#  'ely': 1202,
#  'tol': 687,
#  'rax': 79,
#  'axa': 53,
#  'xas': 23,
#  'raz': 170,
#  'zit': 37,
#  'azo': 220,
#  'rea': 2132,
#  'eac': 487,
#  'eas': 800,
#  'reg': 611,
#  'ege': 302,
#  'eno': 1174,
#  'enu': 286,
#  'nun': 154,
#  'nci': 756,
#  'cia': 841,
#  'bri': 835,
#  'ric': 2565,
#  'ico': 1003,
#  'rid': 1044,
#  'idg': 154,
#  'dga': 27,
#  'gab': 167,
#  'gea': 232,
#  'eab': 390,
#  'edl': 647,
#  'dly': 719,
#  'gem': 191,
#  'ger': 1332,
#  'dgi': 92,
#  'dgm': 19,
#  'gme': 112,
#  'roc': 1227,
#  'com': 1804,
#  'rog': 757,
#  'roo': 927,
#  'ook': 523,
#  'ros': 1762,
#  'osi': 1309,
#  'rot': 1299,
#  'bru': 230,
#  'rup': 231,
#  'upt': 170,
#  'pte': 489,
#  'ptn': 15,
#  'ruz': 11,
#  'uzz': 86,
#  'zzi': 58,
#  'abs': 219,
#  'bsa': 20,
#  'sam': 202,
#  'sar': 495,
#  'rok': 127,
#  'oka': 112,
#  'oki': 243,
#  'kit': 152,
#  'bsc': 86,
#  'sca': 822,
#  'cam': 397,
#  'sce': 676,
#  'ssr': 17,
#  'sro': 33,
#  'oot': 796,
#  'sci': 558,
#  'isi': 1004,
#  'sas': 107,
#  'con': 3548,
#  'ond': 1223,
#  'nsa': 401,
#  'cou': 978,
#  'bse': 131,
#  'see': 338,
#  'sei': 161,
#  'eil': 144,
#  'sen': 992,
#  'nta': 1728,
#  'tee': 475,
#  'ees': 322,
#  'nti': 3163,
#  'tia': 980,
#  'ntm': 52,
#  'tmi': 47,
#  'ntn': 116,
#  'sey': 96,
#  'bsh': 15,
#  'bsi': 70,
#  'nth': 1104,
#  'the': 2988,
#  ...}

# %%
temp = {"a" : 1, 
        "b" : 2, 
        "c" : 3}

# %%
for l in string.ascii_lowercase:
    if(temp.get(l)):
        print("%s in dict" % l)
    print(temp.get(l))
# Out:
# a in dict
# 1
# b in dict
# 2
# c in dict
# 3
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None

# %%
temp.get("z")

# %%
thisdict =	{
  "brand": "Ford",
  "model": "Mustang",
  "year": 1964
}

# %%
thisdict["brand"]
# Out:
# 'Ford'

# %%
ngrams[2][".aa"]
# Out:
# 32

# %%
test_word = "abc_efgh"
idx = test_word.index("_")
max_dim = len(test_word)

# %%
substr_lists = []
input_word = "abc_efgh"
input_word = "." + input_word + "." #pad beginning and end with something to indicate beginning/end
#word = temp_word
#print(input_word)
for i,char in enumerate(input_word):
    if char == "_": #found a blank
        start, end = i, i
        #print(i)
        #get longest substring containing the blank
        while start > 0 and input_word[start-1] != "_":
            start-=1
            #print(start)
        while end < len(input_word) - 1 and input_word[end+1] != "_":
            end += 1
            #print(end)
        #now, turn substring into something to match an n-gram
        substring = input_word[start : end + 1]
        #Ok, this is the LONGEST SUBSTRING CONTAINING ONE UNDERSCORE
        #We now have to break it into grams and add them to the substr_lists

        #I tested the algorithm and this doesn't perform all that well, so instead of only considering the longest substring I will consider ALL substrings and weight them by length...
        for j in range(2, min(6, len(substring)+1)):
            grams = ngrams(substring, j)
            for g in grams:
                if(g.count("_") == 1 and set(ssList) - set({None, "_"}) != set()):
                    substr_lists.append("".join(g))
print(substr_lists)
# Out:
# ['c_', '_e', 'bc_', 'c_e', '_ef', 'abc_', 'bc_e', 'c_ef', '_efg', '.abc_', 'abc_e', 'bc_ef', 'c_efg', '_efgh']

# %%
for g in ngrams(input_word, 3):
    print(g)
# Out:
# ('.', 'a', 'b')
# ('a', 'b', 'c')
# ('b', 'c', '_')
# ('c', '_', 'e')
# ('_', 'e', 'f')
# ('e', 'f', 'g')
# ('f', 'g', 'h')
# ('g', 'h', '.')

# %%
temp = ['.abc_', 'abc_e', 'bc_ef', 'c_efg', '_efgh']

# %%
set("._") - set({".", "_"})
# Out:
# set()

# %%
substr = "abc_efg"
#print(substr)
#print("substring: " + substr)
#substr = string(substr)
max_dimension = len(substr)

#start at max_dim, and work way down to 2
#only consider the longest matches.
dimension = max_dimension
while dimension >= 2:
    #ngramDict = allGrams[dimension-2]

    match_temp_array = []
    idx = substr.find("_") # get the index of the blank in this substring
    #guessableLetters = set(self.alphabet) - set(guess_list)
    
    total_match_count = 0
    for l in string.ascii_lowercase:
        filledSubstr = substr[0:idx] + l + substr[idx+1::]
        
        if(ngramDict.get(filledSubstr)):
            count = ngramDict[filledSubstr]
            match_temp_array.append([l, filledSubstr, count])
            total_match_count += count
            #print(l, count, filledSubstr, sep = " ")
    
    for item in match_temp_array:
        if (item[0] not in guess_list):
            potential_guesses.append([item[0], dimension, item[2] / total_match_count, total_match_count])
    
    if match_temp_array != []:
        dimension -= 1

# %%
substr = "abc_efg"
max_dim = len(substr)
idx = substr.find("_")

dimension = max_dim
while dimension > 1:
    grams = ngrams(substr, dimension)
    substr_grams = ["".join(g) for g in grams if g.count("_") == 1]

    for str in substr_grams:
        print(str)

    



    dimension -= 1
# Out:
# abc_efg
# abc_ef
# bc_efg
# abc_e
# bc_ef
# c_efg
# abc_
# bc_e
# c_ef
# _efg
# bc_
# c_e
# _ef
# c_
# _e

# %%
substr = "c_ef"
max_dim = len(substr)
idx = substr.find("_")

dimension = max_dim
while dimension > 1:
    grams = ngrams(substr, dimension)
    substr_grams = ["".join(g) for g in grams if g.count("_") == 1]

    for str in substr_grams:
        print(str)

    



    dimension -= 1
# Out:
# c_ef
# c_e
# _ef
# c_
# _e

# %%
input_word = "abc_efgh_j"

#Ok, so we need to get the longest substrings in the word that contain ONE blank space.
#first pad beginning and end of word with something, will replace with None later
substr_list = []
input_word = "." + input_word + "." #pad beginning and end with something to indicate beginning/end

for i,char in enumerate(input_word):
    if char == "_": #found a blank
        start, end = i, i
        #print(i)
        #get longest substring containing the blank
        while start > 0 and input_word[start-1] != "_":
            start-=1
            #print(start)
        while end < len(input_word) - 1 and input_word[end+1] != "_":
            end += 1
            #print(end)
        substring = input_word[start : end + 1]
        substr_list.append(substring)
#print(substr_list)

potential_matches = []
for substr in substr_list:
    max_dim = min(len(substr), 5)
    current_dim = max_dim

    while current_dim >= 2:

        grams = ngrams(substr, current_dim)
        subsubstr_list = ["".join(g) for g in grams if g.count("_") == 1]
        #print(subsubstr_list)
        
        for subsubstr in subsubstr_list:
            idx = subsubstr.find("_")
            total_match_count = 0

        #now match stuff here...
        
        current_dim -= 1
# Out:
# ['.abc_efgh', 'efgh_j.']

# %%
# Out:
# ['.abc_', 'abc_e', 'bc_ef', 'c_efg', '_efgh']
# ['abc_', 'bc_e', 'c_ef', '_efg']
# ['bc_', 'c_e', '_ef']
# ['c_', '_e']
# ['efgh_', 'fgh_j', 'gh_j.']
# ['fgh_', 'gh_j', 'h_j.']
# ['gh_', 'h_j', '_j.']
# ['h_', '_j']

# %%
input_word = "abc_efgh_j"

potential_guesses = []
remove_set = set(guess_list)
remove_set.add(None)

#Ok, so we need to get the longest substrings in the word that contain ONE blank space.
#first pad beginning and end of word with something, will replace with None later
substr_lists = []
input_word = "." + input_word + "." #pad beginning and end with something to indicate beginning/end

for i,char in enumerate(input_word):
    if char == "_": #found a blank
        start, end = i, i
        #print(i)
        #get longest substring containing the blank
        while start > 0 and input_word[start-1] != "_":
            start-=1
            #print(start)
        while end < len(input_word) - 1 and input_word[end+1] != "_":
            end += 1
            #print(end)
        substring = input_word[start : end + 1]
        #Ok, this is the LONGEST SUBSTRING CONTAINING ONE UNDERSCORE
        #We now have to break it into grams and add them to the substr_lists

        #I tested the algorithm and this doesn't perform all that well, so instead of only considering the longest substring I will consider ALL substrings and weight them by length...
        #for j in range(2, min(6, len(substring)+1)):
        #    grams = ngrams(substring, j)
        #    for g in grams:
        #        if(g.count("_") == 1 and set(g) - set({".", "_"}) != set()):
        #            substr_lists.append("".join(g))

        #I tested the algorithm AGAIN and it performs WORSE when you consider smaller substrings?
        if len(substring) > 5:
            grams = ngrams(substring, 5)
            for g in grams:
                if(g.count("_") == 1 and set(g) - set({".", "_"}) != set()):
                    substr_lists.append("".join(g))
        else:
            if(substring.count("_") == 1 and set(substring) - set({".", "_"}) != set()):
                    substr_lists.append(substring)
#Ok, now all substrings are in the ssList
#the code is also only letting the longest substring match...
#Ok... so the code can't handle if there is NO match in the set of ngrams, if the substring length is 5, it only checks 5grams for example...
            
#For each substring, need to get the prob of each match, and I am doing this by dividing the prob of each match by the prob of all matches for a given substring.
for substr in substr_lists:
    #print(substr)
    #print("substring: " + substr)
    #substr = string(substr)
    max_dimension = len(substr)

    #start at max_dim, and work way down to 2
    #only consider the longest matches.
    max_dim = len(substr)
    idx = substr.find("_")
    total_match_count = 0

    dimension = max_dim

    #I am doing some repeat work but I modified the code again.
    #substr_lists contains the longest substrings of our word that contain only one blank
    #unless the longest substring is longer than 5 in which case it is broken down into 5-grams.
    #Now, when we are picking words from the dictionary, if we break a word into an n-gram of any size, we are guaranteed to find a match
    #That isn't the case if we pick words from OUTSIDE the dictionary, like on a test set.
    #So, if the substr is length 5, we have to look at SHOOT THIS IS ALL WRONG!!!

    while dimension > 1:
        match_temp_array = []
        grams = ngrams(substr, dimension)
        substr_grams = ["".join(g) for g in grams if g.count("_") == 1]
        ngramDict = allGrams[dimension-2]

        for str in substr_grams:
            for l in string.ascii_lowercase:
                filledSubstr = str[0:idx] + l + str[idx+1::]
                
                if(ngramDict.get(filledSubstr)):
                    count = ngramDict[filledSubstr]
                    match_temp_array.append([l, filledSubstr, count])
                    total_match_count += count
                    #print(l, count, filledSubstr, sep = " ")
        
        for item in match_temp_array:
            if (item[0] not in guess_list):
                potential_guesses.append([item[0], dimension, item[2] / total_match_count, total_match_count])
    
        if len(match_temp_array) > 0:
            break
        

        dimension -= 1







    dimension = max_dimension
    while dimension >= 2:
        ngramDict = allGrams[dimension-2]

        match_temp_array = []
        idx = substr.find("_") # get the index of the blank in this substring
        #guessableLetters = set(self.alphabet) - set(guess_list)
        total_match_count = 0
        for l in string.ascii_lowercase:
            filledSubstr = substr[0:idx] + l + substr[idx+1::]
            
            if(ngramDict.get(filledSubstr)):
                count = ngramDict[filledSubstr]
                match_temp_array.append([l, filledSubstr, count])
                total_match_count += count
                #print(l, count, filledSubstr, sep = " ")
        
        for item in match_temp_array:
            if (item[0] not in guess_list):
                potential_guesses.append([item[0], dimension, item[2] / total_match_count, total_match_count])
        
        if match_temp_array != []:
            dimension -= 1
    
return potential_guesses
